# %% [markdown]
# <a href="https://colab.research.google.com/github/versant2612/jnotebooks/blob/main/kgtk/02_kg_profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kgtk==1.0.1
# Out:
# Collecting kgtk==1.0.1
#   Downloading kgtk-1.0.1-py3-none-any.whl (550 kB)
#      |████████████████████████████████| 550 kB 5.2 MB/s
# Collecting parsley>=1.3
#   Downloading Parsley-1.3-py2.py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 5.3 MB/s
# Requirement already satisfied: plac==1.1.3 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (1.1.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (0.11.2)
# Collecting loguru
#   Downloading loguru-0.5.3-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 3.4 MB/s
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (0.0)
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.1.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 3.4 MB/s
# Collecting redis
#   Downloading redis-4.0.1-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 50.7 MB/s
# Collecting odictliteral
#   Downloading odictliteral-1.0.0.tar.gz (3.1 kB)
# Collecting pycountry
#   Downloading pycountry-20.7.3.tar.gz (10.1 MB)
#      |████████████████████████████████| 10.1 MB 40.9 MB/s
# Collecting rfc3986
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (21.2.0)
# Collecting mgzip>=0.2.1
#   Downloading mgzip-0.2.1.tar.gz (9.6 kB)
# Collecting mypy
#   Downloading mypy-0.910-cp37-cp37m-manylinux2010_x86_64.whl (21.5 MB)
#      |████████████████████████████████| 21.5 MB 1.3 MB/s
# Collecting rltk
#   Downloading rltk-2.0.0a20-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 8.8 MB/s
# Collecting iso-639
#   Downloading iso-639-0.4.5.tar.gz (167 kB)
#      |████████████████████████████████| 167 kB 69.5 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (4.62.3)
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-1.8.5-py3-none-any.whl (26 kB)
# Requirement already satisfied: dill>=0.3.2 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (0.3.4)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (7.4.0)
# Collecting lz4
#   Downloading lz4-3.1.3-cp37-cp37m-manylinux2010_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 67.9 MB/s
# Collecting sh>=1.13
#   Downloading sh-1.14.2-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.5 MB/s
# Collecting shortuuid
#   Downloading shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Collecting rdflib>=6.0.2
#   Downloading rdflib-6.0.2-py3-none-any.whl (407 kB)
#      |████████████████████████████████| 407 kB 60.5 MB/s
# Collecting rdflib-jsonld>=0.6.2
#   Downloading rdflib_jsonld-0.6.2-py2.py3-none-any.whl (4.0 kB)
# Collecting torchbiggraph
#   Downloading torchbiggraph-1.0.0-py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 8.0 MB/s
# Collecting pyrallel.lib==0.0.9
#   Downloading pyrallel.lib-0.0.9-py3-none-any.whl (24 kB)
# Collecting pyshacl>=0.17.1
#   Downloading pyshacl-0.17.2-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 59.5 MB/s
# Collecting etk>=2.2.8
#   Downloading etk-2.2.8-py3-none-any.whl (203 kB)
#      |████████████████████████████████| 203 kB 59.7 MB/s
# Collecting simplejson
#   Downloading simplejson-3.17.6-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 53.1 MB/s
# Collecting typing>=3.6
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 6.3 MB/s
# Requirement already satisfied: multiprocess>=0.70 in /usr/local/lib/python3.7/dist-packages (from pyrallel.lib==0.0.9->kgtk==1.0.1) (0.70.12.2)
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (1.19.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (0.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (1.0.6)
# Requirement already satisfied: srsly<1.1.0,>=0.0.6 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (3.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (1.0.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.0.9 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (0.8.2)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->thinc==7.4.0->kgtk==1.0.1) (4.8.2)
# Requirement already satisfied: pathlib>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.0.1)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2018.9)
# Collecting pygtrie>=2.2
#   Downloading pygtrie-2.4.2.tar.gz (35 kB)
# Requirement already satisfied: python-dateutil>=2.7.2 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2.8.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (0.2.5)
# Collecting langid>=1.1.6
#   Downloading langid-1.1.6.tar.gz (1.9 MB)
#      |████████████████████████████████| 1.9 MB 53.3 MB/s
# Collecting langdetect>=1.0.7
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 67.0 MB/s
# Collecting pyexcel-io>=0.5.6
#   Downloading pyexcel_io-0.6.5-py2.py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 2.3 MB/s
# Requirement already satisfied: chardet>=3.0.4 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (3.0.4)
# Collecting tabula-py>=1.4.3
#   Downloading tabula_py-2.3.0-py3-none-any.whl (12.0 MB)
#      |████████████████████████████████| 12.0 MB 13.9 MB/s
# Requirement already satisfied: urllib3>=1.22 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.24.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.1.0)
# Requirement already satisfied: spacy==2.2.4 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2.2.4)
# Requirement already satisfied: idna>=2.6 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2.10)
# Collecting msgpack-python>=0.5.4
#   Downloading msgpack-python-0.5.6.tar.gz (138 kB)
#      |████████████████████████████████| 138 kB 61.7 MB/s
# Collecting lml>=0.0.1
#   Downloading lml-0.1.0-py2.py3-none-any.whl (10 kB)
# Collecting cytoolz>=0.8.2
#   Downloading cytoolz-0.11.2.tar.gz (481 kB)
#      |████████████████████████████████| 481 kB 57.0 MB/s
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.1.5)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2.23.0)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (4.6.3)
# Collecting msgpack-numpy<0.4.4.0
#   Downloading msgpack_numpy-0.4.3.2-py2.py3-none-any.whl (5.2 kB)
# Collecting pyexcel-xls>=0.5.6
#   Downloading pyexcel_xls-0.7.0-py2.py3-none-any.whl (11 kB)
# Collecting jsonpath-ng>=1.4.3
#   Downloading jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Collecting pyexcel-xlsx>=0.5.6
#   Downloading pyexcel_xlsx-0.6.0-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: wrapt>=1.10.11 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.13.3)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (0.11.2)
# Collecting dateparser>=0.7.0
#   Downloading dateparser-1.1.0-py2.py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 68.1 MB/s
# Requirement already satisfied: decorator>=4.2.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (4.4.2)
# Collecting pyexcel>=0.5.7
#   Downloading pyexcel-0.6.7-py2.py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 5.8 MB/s
# Collecting cssselect>=1.0.3
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: html5lib>=1.0b8 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.0.1)
# Requirement already satisfied: tzlocal>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.5.1)
# Collecting ply>=3.11
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 6.1 MB/s
# Collecting ftfy>=4.4.3
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      |████████████████████████████████| 64 kB 2.6 MB/s
# Requirement already satisfied: jdcal>=1.3 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.4.1)
# Collecting ujson>=1.35
#   Downloading ujson-4.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (214 kB)
#      |████████████████████████████████| 214 kB 65.1 MB/s
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.2 MB/s
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.15.0)
# Requirement already satisfied: pyparsing>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (3.0.6)
# Requirement already satisfied: lxml>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (4.2.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.4->etk>=2.2.8->kgtk==1.0.1) (57.4.0)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.7/dist-packages (from dateparser>=0.7.0->etk>=2.2.8->kgtk==1.0.1) (2019.12.20)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from html5lib>=1.0b8->etk>=2.2.8->kgtk==1.0.1) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->thinc==7.4.0->kgtk==1.0.1) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->thinc==7.4.0->kgtk==1.0.1) (3.10.0.2)
# Requirement already satisfied: msgpack>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from msgpack-numpy<0.4.4.0->etk>=2.2.8->kgtk==1.0.1) (1.0.2)
# Collecting texttable>=0.8.2
#   Downloading texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: xlwt in /usr/local/lib/python3.7/dist-packages (from pyexcel-xls>=0.5.6->etk>=2.2.8->kgtk==1.0.1) (1.3.0)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (from pyexcel-xls>=0.5.6->etk>=2.2.8->kgtk==1.0.1) (1.1.0)
# Collecting openpyxl>=2.6.1
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 60.7 MB/s
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.6.1->pyexcel-xlsx>=0.5.6->etk>=2.2.8->kgtk==1.0.1) (1.1.0)
# Requirement already satisfied: prettytable<3.0.0,>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from pyshacl>=0.17.1->kgtk==1.0.1) (2.4.0)
# Collecting owlrl<6.0.0,>=5.2.3
#   Downloading owlrl-5.2.3-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 5.2 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->etk>=2.2.8->kgtk==1.0.1) (2021.10.8)
# Collecting distro
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from mypy->kgtk==1.0.1) (0.10.2)
# Collecting mypy-extensions<0.5.0,>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting typed-ast<1.5.0,>=1.4.0
#   Downloading typed_ast-1.4.3-cp37-cp37m-manylinux1_x86_64.whl (743 kB)
#      |████████████████████████████████| 743 kB 57.4 MB/s
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting pandas>=0.22.0
#   Downloading pandas-1.3.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 29.0 MB/s
# Requirement already satisfied: Cython>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (0.29.24)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (3.2.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (1.4.1)
# Requirement already satisfied: dask>=0.19.2 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (2.12.0)
# Requirement already satisfied: distributed>=1.23 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (1.25.3)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (7.1.2)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (2.4.0)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (1.3.0)
# Requirement already satisfied: tblib in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (1.7.0)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (5.4.8)
# Requirement already satisfied: tornado>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (5.1.1)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (2.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (3.13)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.0.0->rltk->kgtk==1.0.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.0.0->rltk->kgtk==1.0.1) (0.11.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=1.23->rltk->kgtk==1.0.1) (1.0.1)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 25.6 MB/s
# Collecting tokenizers>=0.10.3
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 44.6 MB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1) (0.11.1+cu111)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1) (1.0.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 48.9 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.1.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 6.3 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->kgtk==1.0.1) (21.3)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 68.9 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->kgtk==1.0.1) (3.4.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 68.9 MB/s
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers->kgtk==1.0.1) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers->kgtk==1.0.1) (3.0.0)
# Requirement already satisfied: h5py>=2.8 in /usr/local/lib/python3.7/dist-packages (from torchbiggraph->kgtk==1.0.1) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.8->torchbiggraph->kgtk==1.0.1) (1.5.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers->kgtk==1.0.1) (7.1.2)
# Building wheels for collected packages: cytoolz, ftfy, langdetect, langid, mgzip, msgpack-python, pygtrie, typing, iso-639, odictliteral, pycountry, sentence-transformers
#   Building wheel for cytoolz (setup.py) ... done
#   Created wheel for cytoolz: filename=cytoolz-0.11.2-cp37-cp37m-linux_x86_64.whl size=1231087 sha256=ccee5753bb4d5f3498f6b485631e1ff36dfdd54c0423f58a1686b89fa01860f0
#   Stored in directory: /root/.cache/pip/wheels/38/70/71/ca13ea3d36ccd0b3d0ec7d7a4ca67522048d695b556bba4f59
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41933 sha256=d7295f47de04aefceee0c4b98aaeaf5be8d70f2c82e178fe7c12d792286728e1
#   Stored in directory: /root/.cache/pip/wheels/19/f5/38/273eb3b5e76dfd850619312f693716ac4518b498f5ffb6f56d
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=1e848badb77ed00d2d17ae567a55af252e6be562b2bb62f9ac95aba16e3df479
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
#   Building wheel for langid (setup.py) ... done
#   Created wheel for langid: filename=langid-1.1.6-py3-none-any.whl size=1941187 sha256=460d6e8f84afb016ff568891d2cd45cd7bf4e26985d0718f468d51a6e4d64670
#   Stored in directory: /root/.cache/pip/wheels/2b/bb/7f/11e4db39477278161e882eadc46fb558949a28b13470fc74b8
#   Building wheel for mgzip (setup.py) ... done
#   Created wheel for mgzip: filename=mgzip-0.2.1-py3-none-any.whl size=10348 sha256=fd9aa2f579d2052bd04f5301e081b561dd7719a5286eb805ad9fb05d7d855f76
#   Stored in directory: /root/.cache/pip/wheels/d9/57/56/34e22ae1ab1ed3c8108a88dc00f43f59e9763e0c6df0da137f
#   Building wheel for msgpack-python (setup.py) ... done
#   Created wheel for msgpack-python: filename=msgpack_python-0.5.6-cp37-cp37m-linux_x86_64.whl size=305465 sha256=0db9d353ab87a9ed19103f5faa523152b50679311aaeaaa152f57907711296fd
#   Stored in directory: /root/.cache/pip/wheels/f8/6c/02/92ebc97f3b99ad5bfc675be2c513f9cb3504fdbe338314f377
#   Building wheel for pygtrie (setup.py) ... done
#   Created wheel for pygtrie: filename=pygtrie-2.4.2-py3-none-any.whl size=19062 sha256=783622a06c248cc767f410254f5e1ac37357568283ee709f476bbd17d8435870
#   Stored in directory: /root/.cache/pip/wheels/d3/f8/ba/1d828b1603ea422686eb694253a43cb3a5901ea4696c1e0603
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26324 sha256=6e5b40ed85e15737dca93f3cc5eae6b42c94446ec5f0652d86f7c9c9b0d61cd7
#   Stored in directory: /root/.cache/pip/wheels/35/f3/15/01aa6571f0a72ee6ae7b827c1491c37a1f72d686fd22b43b0e
#   Building wheel for iso-639 (setup.py) ... done
#   Created wheel for iso-639: filename=iso_639-0.4.5-py3-none-any.whl size=169061 sha256=3c444c1ea96869bd10724658392b48fc3167737bfac38bc512fa285b0e93c981
#   Stored in directory: /root/.cache/pip/wheels/47/60/19/6d020fc92138ed1b113a18271e83ea4b5525fe770cb45b9a2e
#   Building wheel for odictliteral (setup.py) ... done
#   Created wheel for odictliteral: filename=odictliteral-1.0.0-py3-none-any.whl size=3122 sha256=a3b9802fd4e646464ef14b77ae30d3fb25854e01f49282a925e6a839404e2d9d
#   Stored in directory: /root/.cache/pip/wheels/3f/25/10/2ce4f3d7e604b790796f487e5e77a90b544eb2302d0ace109b
#   Building wheel for pycountry (setup.py) ... done
#   Created wheel for pycountry: filename=pycountry-20.7.3-py2.py3-none-any.whl size=10746883 sha256=8e8bc6fe227a241329501d871381c5ba125c06245089c66528f442921856482b
#   Stored in directory: /root/.cache/pip/wheels/57/e8/3f/120ccc1ff7541c108bc5d656e2a14c39da0d824653b62284c6
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=121000 sha256=b8d4a95b11d57039e4f1282bd6936177190f061ac05d6b84f3de8b428143e838
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
# Successfully built cytoolz ftfy langdetect langid mgzip msgpack-python pygtrie typing iso-639 odictliteral pycountry sentence-transformers
# Installing collected packages: isodate, rdflib, pyyaml, lml, typing, tokenizers, texttable, sacremoses, pyexcel-io, ply, pandas, owlrl, openpyxl, huggingface-hub, distro, ujson, typed-ast, transformers, tabula-py, SPARQLWrapper, sentencepiece, rdflib-jsonld, pyshacl, pyrallel.lib, pygtrie, pyexcel-xlsx, pyexcel-xls, pyexcel, mypy-extensions, msgpack-python, msgpack-numpy, langid, langdetect, jsonpath-ng, ftfy, deprecated, dateparser, cytoolz, cssselect, torchbiggraph, simplejson, shortuuid, sh, sentence-transformers, rltk, rfc3986, redis, pycountry, parsley, odictliteral, mypy, mgzip, lz4, loguru, iso-639, etk, kgtk
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 2.5.9
#     Uninstalling openpyxl-2.5.9:
#       Successfully uninstalled openpyxl-2.5.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.4 which is incompatible.
# Successfully installed SPARQLWrapper-1.8.5 cssselect-1.1.0 cytoolz-0.11.2 dateparser-1.1.0 deprecated-1.2.13 distro-1.6.0 etk-2.2.8 ftfy-6.0.3 huggingface-hub-0.1.2 iso-639-0.4.5 isodate-0.6.0 jsonpath-ng-1.5.3 kgtk-1.0.1 langdetect-1.0.9 langid-1.1.6 lml-0.1.0 loguru-0.5.3 lz4-3.1.3 mgzip-0.2.1 msgpack-numpy-0.4.3.2 msgpack-python-0.5.6 mypy-0.910 mypy-extensions-0.4.3 odictliteral-1.0.0 openpyxl-3.0.9 owlrl-5.2.3 pandas-1.3.4 parsley-1.3 ply-3.11 pycountry-20.7.3 pyexcel-0.6.7 pyexcel-io-0.6.5 pyexcel-xls-0.7.0 pyexcel-xlsx-0.6.0 pygtrie-2.4.2 pyrallel.lib-0.0.9 pyshacl-0.17.2 pyyaml-6.0 rdflib-6.0.2 rdflib-jsonld-0.6.2 redis-4.0.1 rfc3986-1.5.0 rltk-2.0.0a20 sacremoses-0.0.46 sentence-transformers-2.1.0 sentencepiece-0.1.96 sh-1.14.2 shortuuid-1.0.8 simplejson-3.17.6 tabula-py-2.3.0 texttable-1.6.4 tokenizers-0.10.3 torchbiggraph-1.0.0 transformers-4.12.5 typed-ast-1.4.3 typing-3.7.4.3 ujson-4.2.0

# %% [markdown]
# # Knowledge Graph Profiling
#
# The goal fo profiling is to produce a summary of the classes, properties and instances present in a KG. Profiling is challenging because it is comptationally expensive as the queries touch large parts of the KG. In this part of the tutorial, you will learn how to use KGTK to profile a KG, and how KGTK addresses the computatinal challenges of computing profiles. Along the way, you will learn advanced uses of the KGTK query command.
#
# This part of the tutorial is divided into multiple subsetions:
# - Counting the number of instances, classes and properties
# - Counting the number of instances of each class, the the most basic form of profiling
# - Extending instance counting to include the instance of all subclasses of a class
# - Generalizing the Wikidata `instance of (P31)` to include `occupation (P106)` and `position held (P39)` so that our profiles include statistics about classes such as `director (P57)`, which in Wikidata don't have instances
# - Counting the number of times each property is used in the instances of each class and all its subclasses; you will learn how to divide a computationally challenging task into simpler queries that you can chain together
# - Customizing the profiles to include items of interest
#
# At the end, you will load the profile data in the browsesr so that you can get more insights into the knowledge present in the tutorial KG.

# %% [markdown]
# ## Preamble: set up the environment and files used in the tutorial

# %%
import os
import numpy as np
import pandas as pd

from kgtk.configure_kgtk_notebooks import ConfigureKGTK
from kgtk.functions import kgtk, kypher

# %%
# Parameters

# Folder on local machine where to create the output and temporary folders
input_path = None
output_path = "/tmp/projects"
project_name = "tutorial-profiling"

# %% [markdown]
# Our Wikidata distribution partitions the knowledge in Wikidata into smaller files that make it possible for you to pick and choose which files you want to use. Our tutorial KG is a subset of Wikidata, and is partitioned in the same way as the full Wikidata. The following is a partial list of all the files:

# %%
files = [
    "all",
    "label",
    "alias",
    "description",
    "external_id",
    "monolingualtext",
    "quantity",
    "string",
    "time",
    "item",
    "wikibase_property",
    "qualifiers",
    "datatypes",
    "p279",
    "p279star",
    "p31",
    "in_degree",
    "out_degree",
    "pagerank_directed",
    "pagerank_undirected"
]
ck = ConfigureKGTK(files)
ck.configure_kgtk(input_graph_path=input_path,
                  output_path=output_path,
                  project_name=project_name)
# Out:
# User home: /root
# Current dir: /content
# KGTK dir: /
# Use-cases dir: //use-cases
# --2021-11-20 20:41:22--  https://github.com/usc-isi-i2/kgtk-tutorial-files/raw/main/datasets/arnold/all.tsv.gz
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/usc-isi-i2/kgtk-notebooks/raw/main/datasets/arnold/all.tsv.gz [following]
# --2021-11-20 20:41:23--  https://github.com/usc-isi-i2/kgtk-notebooks/raw/main/datasets/arnold/all.tsv.gz
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/usc-isi-i2/kgtk-notebooks/main/datasets/arnold/all.tsv.gz [following]
# --2021-11-20 20:41:23--  https://raw.githubusercontent.com/usc-isi-i2/kgtk-notebooks/main/datasets/arnold/all.tsv.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45510513 (43M) [application/octet-stream]
# Saving to: ‘/root/isi-kgtk-tutorial/input/all.tsv.gz.1’
#
#      0K .......... .......... .......... .......... ..........  0% 4.68M 9s
#     50K .......... .......... .......... .......... ..........  0% 4.89M 9s
#    100K .......... .......... .......... .......... ..........  0% 24.2M 7s
#    150K .......... .......... .......... .......... ..........  0% 22.2M 5s
#    200K .......... .......... .......... .......... ..........  0% 8.44M 5s
#    250K .......... .......... .......... .......... ..........  0% 41.4M 5s
#    300K .......... .......... .......... .......... ..........  0% 34.4M 4s
#    350K .......... .......... .......... .......... ..........  0% 49.4M 4s
#    400K .......... .......... .......... .......... ..........  1% 40.9M 3s
#    450K .......... .......... .......... .......... ..........  1% 10.9M 3s
#    500K .......... .......... .......... .......... ..........  1% 34.5M 3s
#    550K .......... .......... .......... .......... ..........  1%  105M 3s
#    600K .......... .......... .......... .......... ..........  1% 44.0M 3s
#    650K .......... .......... .......... .......... ..........  1% 74.1M 3s
#    700K .......... .......... .......... .......... ..........  1% 46.3M 3s
#    750K .......... .......... .......... .......... ..........  1%  192M 2s
#    800K .......... .......... .......... .......... ..........  1%  193M 2s
#    850K .......... .......... .......... .......... ..........  2% 96.5M 2s
#    900K .......... .......... .......... .......... ..........  2%  109M 2s
#    900K .......... .......... .......... .......... .......... 44% 83.3M 0s
#    950K .......... .......... .......... .......... .......... 46%  136M 0s
#   1000K .......... .......... .......... .......... .......... 48% 13.3M 0s
#   1050K .......... .......... .......... .......... .......... 50% 53.5M 0s
#   1100K .......... .......... .......... .......... .......... 53% 39.6M 0s
#   1150K .......... .......... .......... .......... .......... 55% 76.1M 0s
#   1200K .......... .......... .......... .......... .......... 57% 87.9M 0s
#   1250K .......... .......... .......... .......... .......... 60% 53.8M 0s
#   1300K .......... .......... .......... .......... .......... 62% 96.7M 0s
#   1350K .......... .......... .......... .......... .......... 64% 99.0M 0s
#   1400K .......... .......... .......... .......... .......... 67% 81.1M 0s
#   1450K .......... .......... .......... .......... .......... 69% 75.7M 0s
#   1500K .......... .......... .......... .......... .......... 71%  100M 0s
#   1550K .......... .......... .......... .......... .......... 74%  146M 0s
#   1600K .......... .......... .......... .......... .......... 76%  136M 0s
#   1650K .......... .......... .......... .......... .......... 78%  146M 0s
#   1700K .......... .......... .......... .......... .......... 81%  152M 0s
#   1750K .......... .......... .......... .......... .......... 83%  153M 0s
#   1800K .......... .......... .......... .......... .......... 85%  120M 0s
#   1850K .......... .......... .......... .......... .......... 88%  145M 0s
#   1900K .......... .......... .......... .......... .......... 90%  154M 0s
#   1950K .......... .......... .......... .......... .......... 92% 70.7M 0s
#   2000K .......... .......... .......... .......... .......... 95%  155M 0s
#   2050K .......... .......... .......... .......... .......... 97%  126M 0s
#   2100K .......... .......... .......... .......... .......... 99%  157M 0s
#   2150K .......                                               100%  120M=0.06s
#
# 2021-11-20 20:41:34 (34.1 MB/s) - ‘/root/isi-kgtk-tutorial/input/metadata.pagerank.undirected.tsv.gz.1’ saved [2208946/2208946]

# %% [markdown]
# The KGTK setup command defines environment variables for all the files so that you can reuse the Jupyter notebook when you install it on your local machine.

# %%
ck.print_env_variables()
# Out:
# USE_CASES_DIR: //use-cases
# kgtk: kgtk
# TEMP: /tmp/projects/tutorial-profiling/temp.tutorial-profiling
# KGTK_OPTION_DEBUG: false
# EXAMPLES_DIR: //examples
# GRAPH: /root/isi-kgtk-tutorial/input
# KGTK_GRAPH_CACHE: /tmp/projects/tutorial-profiling/temp.tutorial-profiling/wikidata.sqlite3.db
# kypher: kgtk query --graph-cache /tmp/projects/tutorial-profiling/temp.tutorial-profiling/wikidata.sqlite3.db
# OUT: /tmp/projects/tutorial-profiling
# STORE: /tmp/projects/tutorial-profiling/temp.tutorial-profiling/wikidata.sqlite3.db
# KGTK_LABEL_FILE: /root/isi-kgtk-tutorial/input/labels.en.tsv.gz
# all: /root/isi-kgtk-tutorial/input/all.tsv.gz
# label: /root/isi-kgtk-tutorial/input/labels.en.tsv.gz
# alias: /root/isi-kgtk-tutorial/input/aliases.en.tsv.gz
# description: /root/isi-kgtk-tutorial/input/descriptions.en.tsv.gz
# external_id: /root/isi-kgtk-tutorial/input/claims.external-id.tsv.gz
# monolingualtext: /root/isi-kgtk-tutorial/input/claims.monolingualtext.tsv.gz
# quantity: /root/isi-kgtk-tutorial/input/claims.quantity.tsv.gz
# string: /root/isi-kgtk-tutorial/input/claims.string.tsv.gz
# time: /root/isi-kgtk-tutorial/input/claims.time.tsv.gz
# item: /root/isi-kgtk-tutorial/input/claims.wikibase-item.tsv.gz
# wikibase_property: /root/isi-kgtk-tutorial/input/claims.wikibase-property.tsv.gz
# qualifiers: /root/isi-kgtk-tutorial/input/qualifiers.tsv.gz
# datatypes: /root/isi-kgtk-tutorial/input/metadata.property.datatypes.tsv.gz
# p279: /root/isi-kgtk-tutorial/input/derived.P279.tsv.gz
# p279star: /root/isi-kgtk-tutorial/input/derived.P279star.tsv.gz
# p31: /root/isi-kgtk-tutorial/input/derived.P31.tsv.gz
# in_degree: /root/isi-kgtk-tutorial/input/metadata.in_degree.tsv.gz
# out_degree: /root/isi-kgtk-tutorial/input/metadata.out_degree.tsv.gz
# pagerank_directed: /root/isi-kgtk-tutorial/input/metadata.pagerank.directed.tsv.gz
# pagerank_undirected: /root/isi-kgtk-tutorial/input/metadata.pagerank.undirected.tsv.gz

# %% [markdown]
# The KGTK query command (https://kgtk.readthedocs.io/en/latest/transform/query/) uses a database to cache the file used in the queries. In this tutorial, we will populate the cache now to include the files we need so that later. KGTK will populate the cache on demand, the first time you use a file. I like to do it at configuration time to keep all the aliases in one place so that I can quickly come here and see the aliases of all the files.

# %%
# %%time
ck.load_files_into_cache()
# Out:
# kgtk query --graph-cache /tmp/projects/tutorial-profiling/temp.tutorial-profiling/wikidata.sqlite3.db -i "/root/isi-kgtk-tutorial/input/all.tsv.gz" --as all  -i "/root/isi-kgtk-tutorial/input/labels.en.tsv.gz" --as label  -i "/root/isi-kgtk-tutorial/input/aliases.en.tsv.gz" --as alias  -i "/root/isi-kgtk-tutorial/input/descriptions.en.tsv.gz" --as description  -i "/root/isi-kgtk-tutorial/input/claims.external-id.tsv.gz" --as external_id  -i "/root/isi-kgtk-tutorial/input/claims.monolingualtext.tsv.gz" --as monolingualtext  -i "/root/isi-kgtk-tutorial/input/claims.quantity.tsv.gz" --as quantity  -i "/root/isi-kgtk-tutorial/input/claims.string.tsv.gz" --as string  -i "/root/isi-kgtk-tutorial/input/claims.time.tsv.gz" --as time  -i "/root/isi-kgtk-tutorial/input/claims.wikibase-item.tsv.gz" --as item  -i "/root/isi-kgtk-tutorial/input/claims.wikibase-property.tsv.gz" --as wikibase_property  -i "/root/isi-kgtk-tutorial/input/qualifiers.tsv.gz" --as qualifiers  -i "/root/isi-kgtk-tutorial/input/metadata.property.datatypes.tsv.gz" --as datatypes  -i "/root/isi-kgtk-tutorial/input/derived.P279.tsv.gz" --as p279  -i "/root/isi-kgtk-tutorial/input/derived.P279star.tsv.gz" --as p279star  -i "/root/isi-kgtk-tutorial/input/derived.P31.tsv.gz" --as p31  -i "/root/isi-kgtk-tutorial/input/metadata.in_degree.tsv.gz" --as in_degree  -i "/root/isi-kgtk-tutorial/input/metadata.out_degree.tsv.gz" --as out_degree  -i "/root/isi-kgtk-tutorial/input/metadata.pagerank.directed.tsv.gz" --as pagerank_directed  -i "/root/isi-kgtk-tutorial/input/metadata.pagerank.undirected.tsv.gz" --as pagerank_undirected  --limit 3
# Incorrect number of bindings supplied. The current statement uses 4, and there are 3 supplied.
#
# CPU times: user 15.2 ms, sys: 13.5 ms, total: 28.7 ms
# Wall time: 662 ms

# %% [markdown]
# ## Compute global KG statistics
# In this part of the tutorial we will compute global statistics about the number of instances in the KG, the number of properties used to describe all the instances and classes, and the number of classes.

# %% [markdown]
# Total number of edges in our graph:

# %%
# %%bash
# zcat < $all | wc -l
# Out:
# 2654671

# %% [markdown]
# Counting the total number of nodes is a bit harder as nodes can appear in the `node1` poistion or the `node2` position.
# In the queries below we count literals as nodes, as in KGTK they are nodes:
# - list all the nodes that appear in the `node1` position.
# - list all the nodes that appear in the `node2` position.
# - concatenate and deduplicate the two files

# %%
kgtk("""
    query -i all
        --match '(n1)-[id]->(n2)'
        --return 'distinct n1 as id'
        -o $TEMP/node1.tsv
""")

kgtk("""
    query -i all
        --match '(n1)-[id]->(n2)'
        --return 'distinct n2 as id'
        -o $TEMP/node2.tsv
""")

kgtk("""
    cat -i $TEMP/node1.tsv -i $TEMP/node2.tsv
    / compact
""")
# Out:
#                                                         id
# 0          $a United States. $b Department of the Interior
# 1        ((0?[1-9]|[1-2][0-9]|3[0-6])[LRC]?)(/(0?[1-9]|...
# 2        (([0-9]|[1-9][0-9]|1[0-9]{2}|2[0-4][0-9]?|25[0...
# 3                                                  (+20) 2
# 4                                                  (+32) 2
# ...                                                    ...
# 1420765                                                url
# 1420766                                      wikibase-form
# 1420767                                      wikibase-item
# 1420768                                  wikibase-property
# 1420769                                     wikibase-sense
#
# [1420770 rows x 1 columns]

# %% [markdown]
# select count(distinct ?node)
# {select ?s as ?node where ?s ?p ?o
# UNION
#  select ?o as ?node where ?s ?p ?o}

# %% [markdown]
# Counting the number of instances is easy as we can use the `instance of (P31)` property to identify the instances:

# %%
# %%bash
# echo $p279star
# pwd
# Out:
# /root/isi-kgtk-tutorial/input/derived.P279star.tsv.gz
# /content

# %%
# %%time
kgtk("""
    query -i $p279star
        --match '(instance)-[:P31]->(class)'
        --return 'count(distinct instance) as count_instances'
""")
# Out:
# CPU times: user 10.1 ms, sys: 14.9 ms, total: 25 ms
# Wall time: 593 ms
#    count_instances
# 0                0

# %% [markdown]
# select count(?instances) where ?instances wd:p31 ?class

# %% [markdown]
# Counting the number of properties used is also easy: you do a query over all statements in the KG, and count the occurrence of each property:

# %%
# %%time
kgtk("""
    query -i all
        --match '(instance)-[l {label: property}]->(class)'
        --return 'count(distinct property) as count_property'
""")
# Out:
# CPU times: user 16.4 ms, sys: 14.2 ms, total: 30.6 ms
# Wall time: 1.84 s
#    count_property
# 0            3874

# %% [markdown]
# select count(?p) where ?s ?p ?o

# %% [markdown]
# Counting the number of classes is more challenging because the notion of class in Wikidata is implicit. Here, we define **class** to be any item that is involved in a `subclass of (P279)`. Some classes don't have instances, so we cannot use `instance of (P31)` to count classes. The KGTK `p279star` graph is very handy for this task, and for any other task where you want to quickly traverse the `subclass of (P279)`. KGTK defines the `subclass of (transitive) (P279star)` property to record all the superclesses of each class, includng itself.
#
# You can count the number of classes by counting the number of distinct classes that appear as values of `P279star` :

# %%
# %%bash
# zcat < $p279star | wc -l
# pwd
# Out:
# 431383
# /content

# %%
# %%time
kgtk("""
    query -i all
        --match '(class)-[:P279star]->(super_class)'
        --return 'count(distinct super_class) as count_classes'
""")
# Out:
# CPU times: user 11.3 ms, sys: 21.8 ms, total: 33.1 ms
# Wall time: 861 ms
#    count_classes
# 0          14598

# %% [markdown]
# select count(distinct ?class) {select ?o as ?class where ?s owl:subClassOf ?o UNION select ?o as ?class where ?s rdf:type ?o}

# %% [markdown]
# Count the number of qualifiers. All the qualifiers are in a file, so we can count them by getting the number of lines in the file:

# %%
# %%bash
# zcat < $qualifiers | wc -l
# Out:
# 322505

# %% [markdown]
# You can also count the number of qualifier edges using a query, and it is instructive to do it as tis example shows how to access the qualifiers on an edge:
# - The first match clasuse has `[id]`, which binds the variable `id` to the identifier of the edge.
# - The second match clause uses `(id)` in the `node1` position, and puts the identifier of the qualifier edge in the `qualifier_id` variable.
# - The retrun statement returns the count of `qualifier_id`, which is the number of qualifier edges.

# %%
kgtk("""
    query -i all
        --match '
            (n1)-[id]->(n2),
            (id)-[qualifier_id]->(qualifier_value)'
        --return 'count(distinct qualifier_id)'
""")
# Out:
#    count(DISTINCT graph_1_c2."id")
# 0                           455226

# %% [markdown]
# We can enhance the query to show us the distribution of properties used as qualifiers by introducing a variable `qualifier_property` to capture the property:

# %%
# %%time
kgtk("""
    query -i all
        --match '
            (n1)-[id]->(n2),
            (id)-[qualifier_id {label: qualifier_property}]->(qualifier_value)'
        --return 'qualifier_property as node1, "count" as label, count(distinct qualifier_id) as node2'
        --order-by 'cast(node2, int) desc'
    / add-labels
""")
# Out:
# CPU times: user 55.7 ms, sys: 26.8 ms, total: 82.5 ms
# Wall time: 6.85 s
#      node1  label   node2                   node1;label
# 0    P1545  count  134301           'series ordinal'@en
# 1     P585  count   96781            'point in time'@en
# 2     P580  count   33212               'start time'@en
# 3     P459  count   32944     'determination method'@en
# 4     P805  count   19969  'statement is subject of'@en
# ..     ...    ...     ...                           ...
# 719   P945  count       1               'allegiance'@en
# 720   P952  count       1  'ISCO-88 occupation code'@en
# 721    P97  count       1              'noble title'@en
# 722   P974  count       1                'tributary'@en
# 723   P991  count       1     'successful candidate'@en
#
# [724 rows x 4 columns]

# %% [markdown]
# ## Get instance counts for each class
#
# In this part you will do the simplest profiling query where you count the number of direct instancess of each class.
# We can compute the instance counts by retrieving all statements that use `instance of (P31)` and counting the instances for each class.
# We order the result by the number of instances to see the classes that have the most instances.
# You can see that our tutorial KG contains a large number of people, and that there is a long tail of classes with very few instances; this is common in Wikidata, which defines over 1 million classes.

# %%
# %%time
kgtk("""
    query -i all
        --match '(instance)-[:P31]->(class)'
        --return 'class as class, count(distinct instance) as count'
        --order-by 'cast(count, int) desc' 
    / add-labels
""")
# Out:
# CPU times: user 86.4 ms, sys: 24.6 ms, total: 111 ms
# Wall time: 1.92 s
#           class  count                                        class;label
# 0            Q5  13873                                         'human'@en
# 1     Q15221623   3177                            'bilateral relation'@en
# 2        Q11424   2136                                          'film'@en
# 3         Q4022   1550                                         'river'@en
# 4         Q3918    815                                    'university'@en
# ...         ...    ...                                                ...
# 5779    Q995347      1                            'Christian movement'@en
# 5780  Q99566538      1  'Wikidata property for an identifier that gene...
# 5781    Q996839      1                        'fraternal organization'@en
# 5782  Q99960791      1                           'ministry of Andorra'@en
# 5783  Q99972219      1                          'anthropomorphic suid'@en
#
# [5784 rows x 3 columns]

# %% [markdown]
# select ?class count(?instances) where ?instances wd:p31 ?class group by ?class

# %% [markdown]
# We want to add the profiling data back into the KG so that we can use it in queries and look at it in the browser.
# To do so, we create a KGTK graph by using `node1, label, node2` as column headers:

# %%
# %%time
kgtk("""
    query -i all
        --match '(instance)-[:P31]->(class)'
        --return 'class as node1, "P31_count" as label, count(distinct instance) as node2'
        --order-by 'cast(node2, int) desc'
    --limit 10 
""")
# Out:
# CPU times: user 10.9 ms, sys: 15.3 ms, total: 26.2 ms
# Wall time: 835 ms
#        node1      label  node2
# 0         Q5  P31_count  13873
# 1  Q15221623  P31_count   3177
# 2     Q11424  P31_count   2136
# 3      Q4022  P31_count   1550
# 4      Q3918  P31_count    815
# 5   Q4164871  P31_count    645
# 6   Q1549591  P31_count    627
# 7   Q3917681  P31_count    614
# 8  Q19595382  P31_count    595
# 9  Q11862829  P31_count    568

# %% [markdown]
# It is good practice to add identifiers to the edges so that we can add qualifiers later if we desire. To add the identifiers, we chain the query output to the `add-id` command:

# %%
# %%time
kgtk("""
    query -i all
        --match '(instance)-[:P31]->(class)'
        --return 'class as node1, "P31count" as label, count(distinct instance) as node2'
        --order-by 'cast(node2, int) desc' 
    / add-id --id-style wikidata
""")
# Out:
# CPU times: user 112 ms, sys: 41 ms, total: 153 ms
# Wall time: 1.8 s
#           node1     label  node2                         id
# 0            Q5  P31count  13873         Q5-P31count-247e30
# 1     Q15221623  P31count   3177  Q15221623-P31count-61d8c4
# 2        Q11424  P31count   2136     Q11424-P31count-907bdc
# 3         Q4022  P31count   1550      Q4022-P31count-c27484
# 4         Q3918  P31count    815      Q3918-P31count-96da2f
# ...         ...       ...    ...                        ...
# 5779    Q995347  P31count      1    Q995347-P31count-6b86b2
# 5780  Q99566538  P31count      1  Q99566538-P31count-6b86b2
# 5781    Q996839  P31count      1    Q996839-P31count-6b86b2
# 5782  Q99960791  P31count      1  Q99960791-P31count-6b86b2
# 5783  Q99972219  P31count      1  Q99972219-P31count-6b86b2
#
# [5784 rows x 4 columns]

# %% [markdown]
# Now that we saw the steps to create the graph with the counts, we want to output the results to a file using the `-o` option:

# %%
# %%time
kgtk("""
    query -i all
        --match '(instance)-[:P31]->(class)'
        --return 'class as node1, "P31count" as label, count(distinct instance) as node2'
        --order-by 'cast(node2, int) desc'
    / add-id --id-style wikidata
    -o $OUT/metadata.p31.count.tsv
""")
# Out:
# CPU times: user 14.3 ms, sys: 20.5 ms, total: 34.8 ms
# Wall time: 1.72 s

# %% [markdown]
# Confirm that the output file went to the right place:

# %%
# !ls -l $OUT
# Out:
# total 18280
# -rw-r--r-- 1 root root 7897664 Nov 20 20:00 derived.P1963computed.tsv
# -rw-r--r-- 1 root root 1156207 Nov 20 19:58 derived.P31x.tsv
# -rw-r--r-- 1 root root   32115 Nov 20 20:00 derived.Paward_count.tsv
# -rw-r--r-- 1 root root 8605268 Nov 20 20:00 derived.Pproperty_domain.tsv
# -rw-r--r-- 1 root root   51360 Nov 20 20:00 derived.Pproperty_units_used.tsv
# -rw-r--r-- 1 root root  601680 Nov 20 19:58 metadata.p31.count.transitive.tsv
# -rw-r--r-- 1 root root  261137 Nov 20 20:42 metadata.p31.count.tsv
# -rw-r--r-- 1 root root   97973 Nov 20 19:58 metadata.p31x.count.transitive.tsv
# drwxr-xr-x 2 root root    4096 Nov 20 20:42 temp.tutorial-profiling

# %% [markdown]
# Load the `P31count` graph in the KGTK cache so that we can use it in queries later

# %%
kgtk("""
    query -i $OUT/metadata.p31.count.tsv --as p31count --limit 20
""")
# Out:
#         node1     label  node2                         id
# 0          Q5  P31count  13873         Q5-P31count-247e30
# 1   Q15221623  P31count   3177  Q15221623-P31count-61d8c4
# 2      Q11424  P31count   2136     Q11424-P31count-907bdc
# 3       Q4022  P31count   1550      Q4022-P31count-c27484
# 4       Q3918  P31count    815      Q3918-P31count-96da2f
# 5    Q4164871  P31count    645   Q4164871-P31count-3c2308
# 6    Q1549591  P31count    627   Q1549591-P31count-9a3553
# 7    Q3917681  P31count    614   Q3917681-P31count-fa7aec
# 8   Q19595382  P31count    595  Q19595382-P31count-a3aaf5
# 9   Q11862829  P31count    568  Q11862829-P31count-f8818b
# 10  Q15632617  P31count    494  Q15632617-P31count-d18b29
# 11  Q19847637  P31count    477  Q19847637-P31count-6e82b8
# 12   Q1093829  P31count    470   Q1093829-P31count-30eec8
# 13    Q133346  P31count    458    Q133346-P31count-ad21a2
# 14  Q12413618  P31count    447  Q12413618-P31count-c498f3
# 15       Q515  P31count    435       Q515-P31count-5f2703
# 16   Q3024240  P31count    404   Q3024240-P31count-6b3c23
# 17  Q45400320  P31count    399  Q45400320-P31count-0f7854
# 18     Q43229  P31count    394     Q43229-P31count-04d19f
# 19     Q34770  P31count    361     Q34770-P31count-73daa9

# %% [markdown]
# Summary of this section:
# - In this section we computed the count of instances for every class in our KG.
# - We illustrated the use of `instance of (P31)` to do queries.
# - We illustrated common conventions to add identifiers to edges and to save results to files.

# %% [markdown]
# ## Compute `P31count_transitive`, the count of instances of a class including the instances of all the subclasses
#
# Approach:
# - get the class of each instance
# - get all the superclass of the class of each instance
# - for every superclass, count all the instances
#
# > This query will run at the scale of all Wikidata, which contains millions of classes
#
# We add the labels to see the results, not surprisingly, `entity` has the most instances, and the top classes are those at the top of the Wikidata ontology:

# %%
# %%time
kgtk("""
    query -i all
        --match '
            (instance)-[:P31]->(class),
            (class)-[:P279star]->(superclass)'
        --return 'superclass as class, count(distinct instance) as count'
        --order-by 'cast(count, int) desc'
    / add-labels
""")
# Out:
# CPU times: user 171 ms, sys: 38.6 ms, total: 209 ms
# Wall time: 13 s
#           class  count                                  class;label
# 0        Q35120  58496                                  'entity'@en
# 1     Q99527517  38373                       'collection entity'@en
# 2     Q28813620  35555                                     'set'@en
# 3     Q16887380  35533                                   'group'@en
# 4     Q58415929  30837                  'spatio-temporal entity'@en
# ...         ...    ...                                          ...
# 8926  Q99772908      1                  'anthropomorphic equine'@en
# 8927  Q99860490      1  'neurological and physiological symptom'@en
# 8928  Q99960791      1                     'ministry of Andorra'@en
# 8929  Q99969523      1            'anthropomorphic artiodactyla'@en
# 8930  Q99972219      1                    'anthropomorphic suid'@en
#
# [8931 rows x 3 columns]

# %% [markdown]
# Store the results in a file using a new property `P31count_transitive`

# %%
# %%time
kgtk("""
    query -i all 
        --match '
            (instance)-[:P31]->(class),
            (class)-[:P279star]->(superclass)'
        --return 'superclass as node1, "P31count_transitive" as label, count(distinct instance) as node2'
        --order-by 'cast(node2, int) desc'
    / add-id --id-style wikidata
    -o $OUT/metadata.p31.count.transitive.tsv
""")
# Out:
# CPU times: user 79.9 ms, sys: 31.7 ms, total: 112 ms
# Wall time: 14 s

# %% [markdown]
# Find the number of instances of `Q5: human`, `artist: Q483501` and `film director: Q2526255`. There are many instances of human, but only one of artist and zero of film director.

# %%
kgtk("""
    filter -i $OUT/metadata.p31.count.transitive.tsv -p "Q5, Q483501, Q2526255 ;;" / add-labels
""")
# Out:
#      node1  ...  node1;label
# 0       Q5  ...   'human'@en
# 1  Q483501  ...  'artist'@en
#
# [2 rows x 5 columns]

# %% [markdown]
# The reason there are no instances of `artist: Q483501` or `film director: Q2526255`  is that Wikidata uses the property `occupation: P106` to relate people to their occupations, so the connection between human and artist of director is not `instance of: P31`. It would be nice if the browser page for `artist: Q483501` or `film director: Q2526255` would show the number of people with this occupation. DBpedia uses a different model where humans are instances of artist or film director.

# %% [markdown]
# ### Summary of this section
# In this section we:
# - Computed the count of instaces of every class, including all subclasses.
# - Introduced `P279star`, the precomputed transitive closure of the Wikidata `subclass of (P279)` property that allows you to conveniently do queries over all super classes or subclasses of an entity.

# %% [markdown]
# ## Define `P31x`, a generalization of `instance of: P31`
#
# In our KG we are going to define a new property called `instance of (generalized): P31x` that behaves like DBpedia, so that we can ask for instances of `artist: Q483501`.
# We do this by generalizing `occupation: P106` abd `position held: 39` to also behave as `P31` statements.
#
# Approach:
# - Combine `x P31 y`, `x P106 y` and `x P39 y` statements using a new `P31x` predicate

# %% [markdown]
# Use the `filter` to take a peek at the data and see whether our plan makes sense.

# %%
kgtk("""
    filter -i $item -p "; P39, P106 ;"
    / head
    / add-labels
""")
# Out:
#         node1 label  ...         label;label                 node2;label
# 0    Q1000048  P106  ...     'occupation'@en     'university teacher'@en
# 1    Q1000048  P106  ...     'occupation'@en  'classical philologist'@en
# 2  Q100063874   P39  ...  'position held'@en               'director'@en
# 3  Q100066085   P39  ...  'position held'@en               'director'@en
# 4       Q1001  P106  ...     'occupation'@en               'essayist'@en
# 5       Q1001  P106  ...     'occupation'@en       'newspaper editor'@en
# 6       Q1001  P106  ...     'occupation'@en             'journalist'@en
# 7       Q1001  P106  ...     'occupation'@en            'philosopher'@en
# 8       Q1001  P106  ...     'occupation'@en              'barrister'@en
# 9  Q100159381  P106  ...     'occupation'@en                'teacher'@en
#
# [10 rows x 8 columns]

# %% [markdown]
# Select all the `P31`, `P39` and `P106` statements and rewrite them as `P31x` statements, and also make sure that we do this only for humans:

# %%
kgtk("""
    query -i all
        --match '
            (n1)-[:P31]->(:Q5),
            (n1)-[r {label: property}]->(n2)'
        --where 'property in ["P106", "P39", "P31"]'
        --return 'distinct n1 as node1, "P31x" as label, n2 as node2'
        --limit 10
    / add-labels
""")
# Out:
#         node1 label  ...                    node1;label                 node2;label
# 0    Q1000048  P31x  ...          'Franz Zimmermann'@en     'university teacher'@en
# 1    Q1000048  P31x  ...          'Franz Zimmermann'@en  'classical philologist'@en
# 2    Q1000048  P31x  ...          'Franz Zimmermann'@en                  'human'@en
# 3    Q1000061  P31x  ...        'Valentyn Symonenko'@en                  'human'@en
# 4  Q100063874  P31x  ...          'Catherine Musson'@en                  'human'@en
# 5  Q100063874  P31x  ...          'Catherine Musson'@en               'director'@en
# 6  Q100066085  P31x  ...  'Anne-Laurence Mennessier'@en                  'human'@en
# 7  Q100066085  P31x  ...  'Anne-Laurence Mennessier'@en               'director'@en
# 8       Q1001  P31x  ...            'Mahatma Gandhi'@en               'essayist'@en
# 9       Q1001  P31x  ...            'Mahatma Gandhi'@en       'newspaper editor'@en
#
# [10 rows x 5 columns]

# %% [markdown]
# The query needs to be more sophisticated, because the previous query adds the extended `instance of` only to humans. If we don't do this, fictional characters that have occupations end up below `human (Q5)` due to the way the Wikidata ontology is structure. The fix is to concatenate (`cat`)the results of the previuos query with the original `instance of (P31)` graph and to deduplicate (`compact`).
# The resulting graph goes in file `derived.P31x.tsv`:

# %%
# %%time
kgtk("""
    query -i item
        --match '
            (n1)-[:P31]->(:Q5),
            (n1)-[r {label: property}]->(n2)'
        --where 'property in ["P106", "P39", "P31"]'
        --return 'distinct n1 as node1, "P31x" as label, n2 as node2'
    / add-id --id-style wikidata

    / compact
    -o $OUT/derived.P31x.tsv
""")
# Out:
# CPU times: user 15.4 ms, sys: 16.6 ms, total: 32.1 ms
# Wall time: 2.62 s

# %% [markdown]
# Load the `p31x` graph defining our generalized `instance of` property:

# %%
kgtk("""
    query -i $OUT/derived.P31x.tsv --as p31x --limit 20
""")
# Out:
#          node1 label      node2                        id
# 0     Q1000048  P31x   Q1622272    Q1000048-P31x-Q1622272
# 1     Q1000048  P31x  Q16267607   Q1000048-P31x-Q16267607
# 2     Q1000048  P31x         Q5          Q1000048-P31x-Q5
# 3     Q1000061  P31x         Q5          Q1000061-P31x-Q5
# 4   Q100063874  P31x   Q1162163  Q100063874-P31x-Q1162163
# 5   Q100063874  P31x         Q5        Q100063874-P31x-Q5
# 6   Q100066085  P31x   Q1162163  Q100066085-P31x-Q1162163
# 7   Q100066085  P31x         Q5        Q100066085-P31x-Q5
# 8        Q1001  P31x  Q11774202      Q1001-P31x-Q11774202
# 9        Q1001  P31x  Q17351648      Q1001-P31x-Q17351648
# 10       Q1001  P31x   Q1930187       Q1001-P31x-Q1930187
# 11       Q1001  P31x   Q4964182       Q1001-P31x-Q4964182
# 12       Q1001  P31x         Q5             Q1001-P31x-Q5
# 13       Q1001  P31x    Q808967        Q1001-P31x-Q808967
# 14  Q100148353  P31x         Q5        Q100148353-P31x-Q5
# 15  Q100153947  P31x         Q5        Q100153947-P31x-Q5
# 16  Q100153956  P31x         Q5        Q100153956-P31x-Q5
# 17  Q100159381  P31x   Q1162163  Q100159381-P31x-Q1162163
# 18  Q100159381  P31x     Q37226    Q100159381-P31x-Q37226
# 19  Q100159381  P31x         Q5        Q100159381-P31x-Q5

# %% [markdown]
# Now we can fix our `P31count_transitive` property to also include classes such as `film director (Q2526255)`. Use the new `P31x` graph to substitute `P31x` for `P31` in our query that computes the class counts:

# %%
# %%time
kgtk("""
    query -i all -i p31x
        --match '
            p31x: (instance)-[:P31x]->(class),
            all: (class)-[:P279star]->(superclass)'
        --return 'superclass as node1, "P31xcount_transitive" as label, count(distinct instance) as node2'
        --order-by 'cast(node2, int) desc'
    / add-id --id-style wikidata
    -o $OUT/metadata.p31x.count.transitive.tsv
""")
# Out:
# CPU times: user 21 ms, sys: 18.5 ms, total: 39.4 ms
# Wall time: 3.09 s

# %% [markdown]
# Redo our query to get the number of instances of `Q5: human`, `artist: Q483501` and `film director: Q2526255`.
# Now we get more reasonable counts for artist and film directors:

# %%
kgtk("""
    filter -i $OUT/metadata.p31x.count.transitive.tsv -p "Q5, Q483501, Q2526255 ;;" / add-labels
""")
# Out:
#       node1  ...         node1;label
# 0        Q5  ...          'human'@en
# 1   Q483501  ...         'artist'@en
# 2  Q2526255  ...  'film director'@en
#
# [3 rows x 5 columns]

# %% [markdown]
# Find out the classes that appear in the new file that didn't appear in the old file. To do this we use the `ifnotexists` command that can be used to subtract the statements of one grpah from the statements from another graph.
# > Some classes may appear in both graphs and have their counts updated (e.g., artists appeared with a count of 1 before):

# %%
kgtk("""
    ifnotexists -i $OUT/metadata.p31x.count.transitive.tsv
        --filter-on $OUT/metadata.p31.count.transitive.tsv
        --input-keys node1
        --filter-keys node1
    / add-labels
""")
# Out:
#          node1  ...                                        node1;label
# 0      Q713200  ...                             'performing artist'@en
# 1       Q33999  ...                                         'actor'@en
# 2    Q15980804  ...                            'media professional'@en
# 3     Q2285706  ...                            'head of government'@en
# 4     Q3282637  ...                                 'film producer'@en
# ..         ...  ...                                                ...
# 902    Q957729  ...                               'photojournalist'@en
# 903  Q96172702  ...  'Minister General of the Order of Franciscans'@en
# 904    Q978708  ...                  'Prime Minister of East Timor'@en
# 905  Q98084799  ...                     'professional photographer'@en
# 906    Q994779  ...                                      'delegate'@en
#
# [907 rows x 5 columns]

# %% [markdown]
# ### Summary of this section
# In this section we:
# - Computed  `P31x` representing our generalized instance of property. Results in `derived.P31x.tsv`.
# - Computed `P31xcount_transitive` as a revision of `P31count_transitive` to also include counts via occupation and position held links. Results in `metadata.p31x.count.transitive.tsv`.
# - Illustrated how to work with precomputed transitive closures (`P279star`), which enables KGTK to efficiently execute queries that otherwise would be very expensive

# %% [markdown]
# ## Compute the number of times each property appears in a class
#
# In this section we will compute the distribution of the use of properties in every class in th KG.
# We want to know the count of the different properties used in all instance of a class.
# For example, if we look at `film (Q11424)` we want to see what properties are used to describe films, including all subclasses of film.
#
# Computing this distirbution is challenging because as the query below shows, there are many classes in our KG:

# %%
kgtk("""
    query -i all --match '(entity)-[:P279]->(class)' --return 'count(distinct class) as `count of classes`'
""")
# Out:
#    count of classes
# 0              7483

# %% [markdown]
# Approach: we divide the task into two steps:
# - For every entity, compute the set of properties used to describe it, and store this information in `item_properties.tsv`
# - For every class, collect all the instances below it, and count the number of times each property appears in `item_properties.tsv`
#
# The query for the first step is below.
# The first clause of the match clause gets the properties used in every instance of the KG.
# I included a second clause to get the data type of the property, and used the `--where` clause to exlude properties with external identifiers, as there are so many of them, and for the tutorial we want the query to run faster.

# %%
# %%time
kgtk("""
    query -i all
        --match '
            (entity)-[l {label: property}]->(),
            (property)-[:datatype]->(datatype)'
        --where 'datatype != "external-id"' 
        --return 'distinct entity as node1, "Phas_property" as label, property as node2'
    / add-labels
""")
# Out:
# CPU times: user 7.64 s, sys: 2.24 s, total: 9.88 s
# Wall time: 23.8 s
#                                 node1  ...                   node2;label
# 0                               P8874  ...  'applies to jurisdiction'@en
# 1                            Q1001543  ...  'applies to jurisdiction'@en
# 2                          Q100325415  ...  'applies to jurisdiction'@en
# 3                            Q1005422  ...  'applies to jurisdiction'@en
# 4                            Q1006360  ...  'applies to jurisdiction'@en
# ...                               ...  ...                           ...
# 837038                       Q7020999  ...     'successful candidate'@en
# 837039                         Q72251  ...     'successful candidate'@en
# 837040                         Q72472  ...     'successful candidate'@en
# 837041                         Q72835  ...     'successful candidate'@en
# 837042  P991-P1855-Q327959-2d857cd2-0  ...     'successful candidate'@en
#
# [837043 rows x 5 columns]

# %% [markdown]
# The results look good, so we add the identifiers to the edges and store the results in `item_properties.tsv`.

# %%
# %%time
kgtk("""
    query -i all
        --match '
            (property)-[:datatype]->(datatype), 
            (entity)-[l {label: property}]->()'
        --where 'datatype != "external-id"' 
        --return 'distinct entity as node1, "Phas_property" as label, property as node2'
    / add-id --id-style wikidata
    -o $TEMP/item_properties.tsv
""")
# Out:
# CPU times: user 69.2 ms, sys: 21.1 ms, total: 90.3 ms
# Wall time: 11.3 s

# %% [markdown]
# In the second step, we use `P279star` to get all the superclasses of each entity, and then look up the entity in the `item_properties` graph to find the properties it uses.
# We invent a new property called `P1963computed` to store the counts. Wikidata has a property `properties for this type (P1963)` where editors can manually specify the properties that should be used to describe the instance of a class. We are computing the properties bottom up from the data, so we call the property `P1963computed`.
#
# In the return clause, we list `superclass`, and the value of the `property` variable ahead of the `count` clause to tell KGTK that we want to aggregate by superclass and property. We reuse the Wikidata `quantity (P1114)` to record the counts:
#
# > This query is very expensive to run on the full Wikidata as it touches every entity in Wikidata, but it will complete after many hours.

# %%
# %%time
kgtk("""
    query -i all -i p31x -i $TEMP/item_properties.tsv
        --match ' 
            p31x: (entity)-[]->(class), 
            all: (class)-[:P279star]->(superclass),
            item_properties: (entity)-[l]->(property)'
        --return 'distinct superclass as node1, "P1963computed" as label, property as node2, count(distinct l) as P1114' \
        --order-by 'cast(P1114, int) desc'
        --limit 100
    / add-labels
""")
# Out:
# CPU times: user 236 ms, sys: 64.7 ms, total: 301 ms
# Wall time: 45.4 s
#          node1  ...       node2;label
# 0   Q103940464  ...  'instance of'@en
# 1      Q154954  ...  'instance of'@en
# 2      Q159344  ...  'instance of'@en
# 3      Q164509  ...  'instance of'@en
# 4    Q16887380  ...  'instance of'@en
# ..         ...  ...               ...
# 95     Q164509  ...   'occupation'@en
# 96   Q16887380  ...   'occupation'@en
# 97   Q18336849  ...   'occupation'@en
# 98     Q215627  ...   'occupation'@en
# 99   Q23958946  ...   'occupation'@en
#
# [100 rows x 6 columns]

# %% [markdown]
# The results look good, so we store them in `derived.P1963computed.tsv`

# %%
# %%time
kgtk("""
    query -i all -i p31x -i $TEMP/item_properties.tsv
        --match ' 
            p31x: (entity)-[]->(class), 
            all: (class)-[:P279star]->(superclass),
            item_properties: (entity)-[l]->(property)'
        --return 'distinct superclass as node1, "P1963computed" as label, property as node2, count(distinct l) as P1114' 
    / add-id --id-style wikidata
    / normalize --add-id True
    -o $OUT/derived.P1963computed.tsv
""")
# Out:
# CPU times: user 191 ms, sys: 40.5 ms, total: 232 ms
# Wall time: 34.8 s

# %% [markdown]
# Add the new graph to the databse anbd define alias `p1963computed` for it.

# %%
kgtk("""
    query -i $OUT/derived.P1963computed.tsv --as p1963computed --limit 10
""")
# Out:
#                           node1  ...                                         id
# 0                      Q1005815  ...                Q1005815-P1963computed-P103
# 1   Q1005815-P1963computed-P103  ...   Q1005815-P1963computed-P103-P1114-1-0000
# 2                      Q1005815  ...                Q1005815-P1963computed-P106
# 3   Q1005815-P1963computed-P106  ...   Q1005815-P1963computed-P106-P1114-1-0000
# 4                      Q1005815  ...                Q1005815-P1963computed-P108
# 5   Q1005815-P1963computed-P108  ...   Q1005815-P1963computed-P108-P1114-1-0000
# 6                      Q1005815  ...               Q1005815-P1963computed-P1343
# 7  Q1005815-P1963computed-P1343  ...  Q1005815-P1963computed-P1343-P1114-1-0000
# 8                      Q1005815  ...                Q1005815-P1963computed-P140
# 9   Q1005815-P1963computed-P140  ...   Q1005815-P1963computed-P140-P1114-1-0000
#
# [10 rows x 4 columns]

# %% [markdown]
# Let' see the distribution of properties for `film (Q11424)`: ... esse dá erro "Empty set"
# > You can try it for `film director (Q2526255)` or `entity (Q35120)`, which gives you the distribution of all properties in the KG:

# %%
# %%time
kgtk("""
    query -i p1963computed
        --match '(class:Q2526255)-[l:P1963computed]->(property),
            (l)-[:P1114]->(quantity)'
        --return 'distinct class as class, property as property, quantity as count'
        --order-by 'cast(count, int) desc'
    / add-labels
""")
# Out:
# CPU times: user 21 ms, sys: 17.7 ms, total: 38.7 ms
# Wall time: 2.04 s
#         class property  count         class;label               property;label
# 0    Q2526255     P106    674  'film director'@en              'occupation'@en
# 1    Q2526255      P31    674  'film director'@en             'instance of'@en
# 2    Q2526255      P21    673  'film director'@en           'sex or gender'@en
# 3    Q2526255     P569    665  'film director'@en           'date of birth'@en
# 4    Q2526255      P27    656  'film director'@en  'country of citizenship'@en
# ..        ...      ...    ...                 ...                          ...
# 96   Q2526255     P582      1  'film director'@en                'end time'@en
# 97   Q2526255    P6758      1  'film director'@en   'supported sports team'@en
# 98   Q2526255     P740      1  'film director'@en   'location of formation'@en
# 99   Q2526255     P802      1  'film director'@en                 'student'@en
# 100  Q2526255     P898      1  'film director'@en       'IPA transcription'@en
#
# [101 rows x 5 columns]

# %% [markdown]
# Store the resulting graph in `derived.Pproperty_domain.tsv` and define the alias `property_domain` for it in the database:

# %%
# %%time
kgtk("""
    query -i p1963computed
        --match '
            (class)-[l:P1963computed]->(property),
            (l)-[:P1114]->(quantity)'
        --return 'distinct property as node1, "Pproperty_domain" as label, class as node2, quantity as P1114'
        --order-by 'property, cast(P1114, int) desc'
    / add-id --id-style wikidata
    / normalize --add-id True
    -o $OUT/derived.Pproperty_domain.tsv
""")
# Out:
# CPU times: user 26.3 ms, sys: 14.4 ms, total: 40.7 ms
# Wall time: 3.4 s

# %%
kgtk("query -i $OUT/derived.Pproperty_domain.tsv --as property_domain --limit 10")
# Out:
#                               node1  ...                                               id
# 0                              P101  ...                 P101-Pproperty_domain-Q103940464
# 1  P101-Pproperty_domain-Q103940464  ...  P101-Pproperty_domain-Q103940464-P1114-353-0000
# 2                              P101  ...                    P101-Pproperty_domain-Q154954
# 3     P101-Pproperty_domain-Q154954  ...     P101-Pproperty_domain-Q154954-P1114-353-0000
# 4                              P101  ...                    P101-Pproperty_domain-Q159344
# 5     P101-Pproperty_domain-Q159344  ...     P101-Pproperty_domain-Q159344-P1114-353-0000
# 6                              P101  ...                    P101-Pproperty_domain-Q164509
# 7     P101-Pproperty_domain-Q164509  ...     P101-Pproperty_domain-Q164509-P1114-353-0000
# 8                              P101  ...                  P101-Pproperty_domain-Q16887380
# 9   P101-Pproperty_domain-Q16887380  ...   P101-Pproperty_domain-Q16887380-P1114-353-0000
#
# [10 rows x 4 columns]

# %% [markdown]
# Let's see the distribution of classes for `cast member(P161)`. We restrict the results to be subclasses of `visual artwork (Q4502142)` because otherwise the results contain too many of the abstract classes. We see that property `cast member(P161)` is defined for film and subclasses of film:

# %%
kgtk("""
    query -i property_domain -i all
        --match '
            all: (class)-[:P279star]->(:Q16887380), 
            property_domain: (property:P101)-[l:Pproperty_domain]->(class),
            property_domain: (l)-[:P1114]->(quantity)'
        --return 'distinct property as node1, "Pproperty_domain" as label, class as node2, quantity as P1114'
        --order-by 'property, cast(P1114, int) desc'
        --limit 10
    / add-labels
""")
# Out:
#   node1             label  ...         node1;label                   node2;label
# 0  P101  Pproperty_domain  ...  'field of work'@en                 'omnivore'@en
# 1  P101  Pproperty_domain  ...  'field of work'@en                    'group'@en
# 2  P101  Pproperty_domain  ...  'field of work'@en  'organisms by adaptation'@en
# 3  P101  Pproperty_domain  ...  'field of work'@en                    'human'@en
# 4  P101  Pproperty_domain  ...  'field of work'@en             'professional'@en
# 5  P101  Pproperty_domain  ...  'field of work'@en                  'creator'@en
# 6  P101  Pproperty_domain  ...  'field of work'@en                   'author'@en
# 7  P101  Pproperty_domain  ...  'field of work'@en                   'writer'@en
# 8  P101  Pproperty_domain  ...  'field of work'@en       'non-fiction writer'@en
# 9  P101  Pproperty_domain  ...  'field of work'@en               'researcher'@en
#
# [10 rows x 6 columns]

# %% [markdown]
# ### Summary of this section
# In this section we:
# - Computed  `P1963computed`, to record the frequence of the use of properties in every class.
# - Used `P1963computed` to see the distribution of properties for a few classes.
# - Illustrated the ability to break down very expensive queries into simpler steps.
# - Illustrated a KGTK feature that allows you to use the results of one query as a new graph (`$TEMP/item_properties.tsv`) that can be integrated into other queries.

# %% [markdown]
# ## Compute the distribution of units for quantity properties
# This part of the tutorial illustrates how to work with KGTK structured literals:
# - quantities: composed of a numeric value followed by the identifier of a unit, quantities can also define tolerances
# - dates and times: composed of an ISO-formatted date, followed by a numeric precision indicator, and sometimes by a calendar
# - monolingual strings: composed of a unicode string followed by a language tag
#
# Additional documentation on the KGTK file format is in https://kgtk.readthedocs.io/en/latest/specification/
# and documentation for the functions to operate on structured literals within queries is in https://kgtk.readthedocs.io/en/latest/transform/query/
#
# Below is a specific example of how to query the units in structured literals. THe objective in the example is to compute a distribution of the units used in all properties that store quantities.
# The query uses the `quantity` graph, which contains all properties whose values are quantities.
#
# The results of the query are interesting as we see some inconsistencies in the data present in our small subset of Wikidata.
# For example, most instances of `population (P1082)` have no units `point in time (Q186408)`, one has unit `Habitants (Q15621516)`, neither of which are units of `unit of measurement (Q47574)`

# %%
kgtk("""
    query -i quantity
        --match '(n1)-[l {label: property}]->(quantity)'
        --return 'distinct property as node1, "Pproperty_units_used" as label, kgtk_quantity_wd_units(quantity) as node2, count(distinct l) as P1114'
        --order-by 'property, cast(P1114, int) desc'
    / add-labels
""")
# Out:
#      node1  ...            node2;label
# 0    P1081  ...                    NaN
# 1    P1082  ...                    NaN
# 2    P1082  ...     'point in time'@en
# 3    P1082  ...         'Habitants'@en
# 4    P1082  ...             'circa'@en
# ..     ...  ...                    ...
# 418  P8476  ...                    NaN
# 419  P8477  ...                    NaN
# 420  P8687  ...                    NaN
# 421  P8843  ...                    NaN
# 422  P8887  ...  'square kilometre'@en
#
# [423 rows x 6 columns]

# %% [markdown]
# We will store the units graph in `derived.Pproperty_units_used.tsv`. The final query includes a `where` clause to filter out the NULL values.

# %%
kgtk("""
    query -i quantity
        --match '(n1)-[l {label: property}]->(quantity)'
        --where 'kgtk_quantity_wd_units(quantity) IS NOT NULL'
        --return 'distinct property as node1, "Pproperty_units_used" as label, kgtk_quantity_wd_units(quantity) as node2, count(distinct l) as P1114'
        --order-by 'property, cast(P1114, int) desc'
    / add-id --id-style wikidata
    / normalize --add-id True
    -o $OUT/derived.Pproperty_units_used.tsv
""")

kgtk("query -i $OUT/derived.Pproperty_units_used.tsv --as property_units_used --limit 10")
# Out:
#                                   node1  ...                                                 id
# 0                                 P1082  ...                 P1082-Pproperty_units_used-Q186408
# 1    P1082-Pproperty_units_used-Q186408  ...    P1082-Pproperty_units_used-Q186408-P1114-2-0000
# 2                                 P1082  ...               P1082-Pproperty_units_used-Q15621516
# 3  P1082-Pproperty_units_used-Q15621516  ...  P1082-Pproperty_units_used-Q15621516-P1114-1-0000
# 4                                 P1082  ...                P1082-Pproperty_units_used-Q5727902
# 5   P1082-Pproperty_units_used-Q5727902  ...   P1082-Pproperty_units_used-Q5727902-P1114-1-0000
# 6                                 P1083  ...               P1083-Pproperty_units_used-Q44666669
# 7  P1083-Pproperty_units_used-Q44666669  ...  P1083-Pproperty_units_used-Q44666669-P1114-2-0000
# 8                                 P1083  ...                  P1083-Pproperty_units_used-Q42177
# 9     P1083-Pproperty_units_used-Q42177  ...     P1083-Pproperty_units_used-Q42177-P1114-1-0000
#
# [10 rows x 4 columns]

# %% [markdown]
# ### Summary of this section
# In this section we:
# - Computed the distribution of the units used for properties that store quantities
# - Found examples of inappropriate use of units of measure in Wikidata
# - Illustrated how to use functions in `query` to extract elements from structured literals

# %% [markdown]
# ## Compute the number of awards by sex or gender of the receiver

# %% [markdown]
# First, get a distirbution of the `sex or gender (P21)` of people in our graph.
# The distribution is skewed, perhaps because it is skewed in Wikidata or a result of how the tutorial graph was constructed.

# %%
kgtk("""
    query -i all
        --match '
            (person)-[:P31]->(:Q5),
            (person)-[:P21]->(sex_or_gender)'
        --return 'distinct sex_or_gender as sex_or_gender, count(distinct person) as count'
    / add-labels
""")
# Out:
#   sex_or_gender  count sex_or_gender;label
# 0      Q6581072   1783         'female'@en
# 1      Q6581097   8111           'male'@en

# %% [markdown]
# Below, we compute the distirbution of `sex or gender (P21)`  per type of award. We use the property `award received (P166)` to extract the awards that people received.
#
# We create a new property `Paward_count` to record the count, and put the `sex or gender (P21)` as a qualifier.

# %%
# %%time
kgtk("""
    query -i all
        --match '
            (actor)-[:P31]->(:Q5),
            (actor)-[:P21]->(sex_or_gender),
            (actor)-[:P166]->(award)-[:P31]->(award_type)'
        --return 'distinct award_type as node1, "Paward_count" as label, sex_or_gender as P21, count(distinct actor) as node2'
        --order-by 'award_type'
    / add-labels
""")
# Out:
# CPU times: user 26.3 ms, sys: 22.1 ms, total: 48.4 ms
# Wall time: 2.77 s
#           node1         label  ...                         node1;label    P21;label
# 0    Q101007233  Paward_count  ...       'film critics association'@en    'male'@en
# 1      Q1011547  Paward_count  ...             'Golden Globe Award'@en  'female'@en
# 2      Q1011547  Paward_count  ...             'Golden Globe Award'@en    'male'@en
# 3    Q101251494  Paward_count  ...                           'star'@en    'male'@en
# 4      Q1044427  Paward_count  ...           'Primetime Emmy Award'@en  'female'@en
# ..          ...           ...  ...                                 ...          ...
# 220   Q96474707  Paward_count  ...                 'honorary award'@en    'male'@en
# 221   Q96474709  Paward_count  ...  'award for best visual effects'@en  'female'@en
# 222   Q96474709  Paward_count  ...  'award for best visual effects'@en    'male'@en
# 223     Q973011  Paward_count  ...                 'campaign medal'@en    'male'@en
# 224   Q97551638  Paward_count  ...                    'merit order'@en    'male'@en
#
# [225 rows x 6 columns]

# %% [markdown]
# Store the new `Paward_count` graph in a file and define the alias `award_count` for it

# %%
# %%time
kgtk("""
    query -i all
        --match '
            (actor)-[:P31]->(:Q5),
            (actor)-[:P21]->(sex_or_gender),
            (actor)-[:P166]->(award)-[:P31]->(award_type)'
        --return 'distinct award_type as node1, "Paward_count" as label, sex_or_gender as P21, count(distinct actor) as node2'
        --order-by 'award_type'
    / add-id --id-style wikidata
    / normalize --add-id True
    -o $OUT/derived.Paward_count.tsv
""")
# Out:
# CPU times: user 22.7 ms, sys: 24.4 ms, total: 47.1 ms
# Wall time: 2.98 s

# %%
kgtk("query -i $OUT/derived.Paward_count.tsv --as award_count --limit 10")
# Out:
#                             node1  ...                                                id
# 0                      Q101007233  ...                    Q101007233-Paward_count-6b86b2
# 1  Q101007233-Paward_count-6b86b2  ...  Q101007233-Paward_count-6b86b2-P21-Q6581097-0000
# 2                        Q1011547  ...                      Q1011547-Paward_count-aea921
# 3    Q1011547-Paward_count-aea921  ...    Q1011547-Paward_count-aea921-P21-Q6581072-0000
# 4                        Q1011547  ...                      Q1011547-Paward_count-73475c
# 5    Q1011547-Paward_count-73475c  ...    Q1011547-Paward_count-73475c-P21-Q6581097-0000
# 6                      Q101251494  ...                    Q101251494-Paward_count-c23560
# 7  Q101251494-Paward_count-c23560  ...  Q101251494-Paward_count-c23560-P21-Q6581097-0000
# 8                        Q1044427  ...                      Q1044427-Paward_count-2c6242
# 9    Q1044427-Paward_count-2c6242  ...    Q1044427-Paward_count-2c6242-P21-Q6581072-0000
#
# [10 rows x 4 columns]

# %% [markdown]
# ### Summary of this section
# In this section we:
# - Profiled awards to find the gender or sex of awardees, and found that males appear more frequently. We don't know if it is a skew in Wikidata or the real world.
# - Defined a new property to hold the data so that it can be shown in the browser.

# %%
kgtk("""
    query -i all
        --match '
            (award)-[P31]->(award_type)-[:P279star]->(:Q4220917)'
        --return 'distinct award_type as award_type'
    / add-labels
""")
# Out:
#    award_type                                 award_type;label
# 0    Q1011547                          'Golden Globe Award'@en
# 1     Q106301   'Academy Award for Best Supporting Actress'@en
# 2     Q110145                            'MTV Movie Awards'@en
# 3    Q1111310            'Directors Guild of America Award'@en
# 4    Q1131772  'Saturn Award for Best Science Fiction Film'@en
# ..        ...                                              ...
# 90  Q96474700                   'award for best screenplay'@en
# 91  Q96474701           'award for best adapted screenplay'@en
# 92  Q96474704      'award for best makeup and hairdressing'@en
# 93  Q96474707                              'honorary award'@en
# 94  Q96474709               'award for best visual effects'@en
#
# [95 rows x 2 columns]
