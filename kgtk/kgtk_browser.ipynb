# %% [markdown]
# <a href="https://colab.research.google.com/github/versant2612/jnotebooks/blob/main/kgtk/kgtk_browser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kgtk==1.0.1
# Out:
# Collecting kgtk==1.0.1
#   Downloading kgtk-1.0.1-py3-none-any.whl (550 kB)
#      |████████████████████████████████| 550 kB 9.7 MB/s
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-1.8.5-py3-none-any.whl (26 kB)
# Collecting iso-639
#   Downloading iso-639-0.4.5.tar.gz (167 kB)
#      |████████████████████████████████| 167 kB 48.0 MB/s
# Requirement already satisfied: seaborn in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (0.11.2)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (0.0)
# Collecting pyshacl>=0.17.1
#   Downloading pyshacl-0.17.2-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 36.8 MB/s
# Collecting odictliteral
#   Downloading odictliteral-1.0.0.tar.gz (3.1 kB)
# Collecting pycountry
#   Downloading pycountry-20.7.3.tar.gz (10.1 MB)
#      |████████████████████████████████| 10.1 MB 14.7 MB/s
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.1.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 8.5 MB/s
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (7.4.0)
# Collecting torchbiggraph
#   Downloading torchbiggraph-1.0.0-py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 9.9 MB/s
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (21.2.0)
# Collecting rfc3986
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting sh>=1.13
#   Downloading sh-1.14.2-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 6.7 MB/s
# Collecting rltk
#   Downloading rltk-2.0.0a20-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 12.0 MB/s
# Collecting mgzip>=0.2.1
#   Downloading mgzip-0.2.1.tar.gz (9.6 kB)
# Collecting lz4
#   Downloading lz4-3.1.3-cp37-cp37m-manylinux2010_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 45.6 MB/s
# Collecting redis
#   Downloading redis-4.0.1-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 24.2 MB/s
# Collecting parsley>=1.3
#   Downloading Parsley-1.3-py2.py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 9.9 MB/s
# Collecting shortuuid
#   Downloading shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Collecting etk>=2.2.8
#   Downloading etk-2.2.8-py3-none-any.whl (203 kB)
#      |████████████████████████████████| 203 kB 59.4 MB/s
# Collecting mypy
#   Downloading mypy-0.910-cp37-cp37m-manylinux2010_x86_64.whl (21.5 MB)
#      |████████████████████████████████| 21.5 MB 1.4 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (4.62.3)
# Requirement already satisfied: dill>=0.3.2 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (0.3.4)
# Collecting rdflib>=6.0.2
#   Downloading rdflib-6.0.2-py3-none-any.whl (407 kB)
#      |████████████████████████████████| 407 kB 45.1 MB/s
# Requirement already satisfied: plac==1.1.3 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (1.1.3)
# Collecting rdflib-jsonld>=0.6.2
#   Downloading rdflib_jsonld-0.6.2-py2.py3-none-any.whl (4.0 kB)
# Collecting pyrallel.lib==0.0.9
#   Downloading pyrallel.lib-0.0.9-py3-none-any.whl (24 kB)
# Collecting simplejson
#   Downloading simplejson-3.17.6-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 40.6 MB/s
# Collecting loguru
#   Downloading loguru-0.5.3-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 5.1 MB/s
# Collecting typing>=3.6
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 9.7 MB/s
# Requirement already satisfied: multiprocess>=0.70 in /usr/local/lib/python3.7/dist-packages (from pyrallel.lib==0.0.9->kgtk==1.0.1) (0.70.12.2)
# Requirement already satisfied: preshed<3.1.0,>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (3.0.6)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=0.0.6 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.0.9 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (0.8.2)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (2.0.6)
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (1.19.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (1.0.6)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->thinc==7.4.0->kgtk==1.0.1) (4.8.2)
# Collecting ply>=3.11
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 7.3 MB/s
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.1.5)
# Requirement already satisfied: jdcal>=1.3 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.4.1)
# Collecting tabula-py>=1.4.3
#   Downloading tabula_py-2.3.0-py3-none-any.whl (12.0 MB)
#      |████████████████████████████████| 12.0 MB 96 kB/s
# Collecting pyexcel-xls>=0.5.6
#   Downloading pyexcel_xls-0.7.0-py2.py3-none-any.whl (11 kB)
# Collecting cytoolz>=0.8.2
#   Downloading cytoolz-0.11.2.tar.gz (481 kB)
#      |████████████████████████████████| 481 kB 48.0 MB/s
# Requirement already satisfied: wrapt>=1.10.11 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.13.3)
# Collecting pygtrie>=2.2
#   Downloading pygtrie-2.4.2.tar.gz (35 kB)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.1.0)
# Collecting ftfy>=4.4.3
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      |████████████████████████████████| 64 kB 3.4 MB/s
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2018.9)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 4.6 MB/s
# Requirement already satisfied: pyparsing>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2.4.7)
# Requirement already satisfied: chardet>=3.0.4 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (3.0.4)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (4.6.3)
# Requirement already satisfied: python-dateutil>=2.7.2 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2.8.2)
# Collecting pyexcel-io>=0.5.6
#   Downloading pyexcel_io-0.6.5-py2.py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 2.9 MB/s
# Collecting pyexcel>=0.5.7
#   Downloading pyexcel-0.6.7-py2.py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 9.6 MB/s
# Collecting langdetect>=1.0.7
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 50.8 MB/s
# Collecting msgpack-python>=0.5.4
#   Downloading msgpack-python-0.5.6.tar.gz (138 kB)
#      |████████████████████████████████| 138 kB 71.6 MB/s
# Requirement already satisfied: pathlib>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.0.1)
# Collecting pyexcel-xlsx>=0.5.6
#   Downloading pyexcel_xlsx-0.6.0-py2.py3-none-any.whl (9.6 kB)
# Collecting jsonpath-ng>=1.4.3
#   Downloading jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Requirement already satisfied: lxml>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (4.2.6)
# Requirement already satisfied: tzlocal>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.5.1)
# Collecting cssselect>=1.0.3
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting ujson>=1.35
#   Downloading ujson-4.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (214 kB)
#      |████████████████████████████████| 214 kB 66.2 MB/s
# Collecting dateparser>=0.7.0
#   Downloading dateparser-1.1.0-py2.py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 60.3 MB/s
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (0.2.5)
# Collecting lml>=0.0.1
#   Downloading lml-0.1.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: idna>=2.6 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2.10)
# Collecting langid>=1.1.6
#   Downloading langid-1.1.6.tar.gz (1.9 MB)
#      |████████████████████████████████| 1.9 MB 52.1 MB/s
# Requirement already satisfied: decorator>=4.2.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (4.4.2)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2.23.0)
# Requirement already satisfied: spacy==2.2.4 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2.2.4)
# Collecting msgpack-numpy<0.4.4.0
#   Downloading msgpack_numpy-0.4.3.2-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: urllib3>=1.22 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.24.3)
# Requirement already satisfied: html5lib>=1.0b8 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.0.1)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (0.11.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.4->etk>=2.2.8->kgtk==1.0.1) (57.4.0)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.7/dist-packages (from dateparser>=0.7.0->etk>=2.2.8->kgtk==1.0.1) (2019.12.20)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from html5lib>=1.0b8->etk>=2.2.8->kgtk==1.0.1) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->thinc==7.4.0->kgtk==1.0.1) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->thinc==7.4.0->kgtk==1.0.1) (3.10.0.2)
# Requirement already satisfied: msgpack>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from msgpack-numpy<0.4.4.0->etk>=2.2.8->kgtk==1.0.1) (1.0.2)
# Collecting texttable>=0.8.2
#   Downloading texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: xlwt in /usr/local/lib/python3.7/dist-packages (from pyexcel-xls>=0.5.6->etk>=2.2.8->kgtk==1.0.1) (1.3.0)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (from pyexcel-xls>=0.5.6->etk>=2.2.8->kgtk==1.0.1) (1.1.0)
# Collecting openpyxl>=2.6.1
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 30.4 MB/s
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.6.1->pyexcel-xlsx>=0.5.6->etk>=2.2.8->kgtk==1.0.1) (1.1.0)
# Requirement already satisfied: prettytable<3.0.0,>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from pyshacl>=0.17.1->kgtk==1.0.1) (2.4.0)
# Collecting owlrl<6.0.0,>=5.2.3
#   Downloading owlrl-5.2.3-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 6.3 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->etk>=2.2.8->kgtk==1.0.1) (2021.10.8)
# Collecting distro
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting mypy-extensions<0.5.0,>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from mypy->kgtk==1.0.1) (0.10.2)
# Collecting typed-ast<1.5.0,>=1.4.0
#   Downloading typed_ast-1.4.3-cp37-cp37m-manylinux1_x86_64.whl (743 kB)
#      |████████████████████████████████| 743 kB 29.3 MB/s
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (3.2.2)
# Collecting pandas>=0.22.0
#   Downloading pandas-1.3.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 37.5 MB/s
# Requirement already satisfied: distributed>=1.23 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (1.25.3)
# Requirement already satisfied: Cython>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (0.29.24)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (1.4.1)
# Requirement already satisfied: dask>=0.19.2 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (2.12.0)
# Requirement already satisfied: tblib in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (1.7.0)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (7.1.2)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (2.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (3.13)
# Requirement already satisfied: tornado>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (5.1.1)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (5.4.8)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (2.0.0)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (1.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.0.0->rltk->kgtk==1.0.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.0.0->rltk->kgtk==1.0.1) (0.11.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=1.23->rltk->kgtk==1.0.1) (1.0.1)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 46.1 MB/s
# Collecting tokenizers>=0.10.3
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 40.4 MB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1) (0.11.1+cu111)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1) (1.0.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 28.9 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.1.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 8.2 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->kgtk==1.0.1) (21.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->kgtk==1.0.1) (3.3.2)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 37.9 MB/s
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 38.9 MB/s
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers->kgtk==1.0.1) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers->kgtk==1.0.1) (3.0.0)
# Requirement already satisfied: h5py>=2.8 in /usr/local/lib/python3.7/dist-packages (from torchbiggraph->kgtk==1.0.1) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.8->torchbiggraph->kgtk==1.0.1) (1.5.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers->kgtk==1.0.1) (7.1.2)
# Building wheels for collected packages: cytoolz, ftfy, langdetect, langid, mgzip, msgpack-python, pygtrie, typing, iso-639, odictliteral, pycountry, sentence-transformers
#   Building wheel for cytoolz (setup.py) ... done
#   Created wheel for cytoolz: filename=cytoolz-0.11.2-cp37-cp37m-linux_x86_64.whl size=1231138 sha256=00e60d31e1b60ff8de1ceec611cf798b5cde5784dd4977c22b6c99d0e7e0cdfb
#   Stored in directory: /root/.cache/pip/wheels/38/70/71/ca13ea3d36ccd0b3d0ec7d7a4ca67522048d695b556bba4f59
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41933 sha256=d34dbab42e24404b844ee498004b59300cf2c453392927e63df461d800ad3fbd
#   Stored in directory: /root/.cache/pip/wheels/19/f5/38/273eb3b5e76dfd850619312f693716ac4518b498f5ffb6f56d
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=4fa1802fdccf2e94365062bcb1cf1c45a9ecacc03d154623e3f93834159e4ae7
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
#   Building wheel for langid (setup.py) ... done
#   Created wheel for langid: filename=langid-1.1.6-py3-none-any.whl size=1941187 sha256=2050c091ac4420e670cf31fa3bcb78e9eb584cfb9eedd5b3daa4cfe04e83e977
#   Stored in directory: /root/.cache/pip/wheels/2b/bb/7f/11e4db39477278161e882eadc46fb558949a28b13470fc74b8
#   Building wheel for mgzip (setup.py) ... done
#   Created wheel for mgzip: filename=mgzip-0.2.1-py3-none-any.whl size=10348 sha256=ff16624f59a7787e5aeb9339553cc6bfe51c439d46d17fe977c22875ed303830
#   Stored in directory: /root/.cache/pip/wheels/d9/57/56/34e22ae1ab1ed3c8108a88dc00f43f59e9763e0c6df0da137f
#   Building wheel for msgpack-python (setup.py) ... done
#   Created wheel for msgpack-python: filename=msgpack_python-0.5.6-cp37-cp37m-linux_x86_64.whl size=305460 sha256=f4b02fcd7393d84a1211b91a9941e36a6f8de03041fb9c78c99cf8d115ed99e9
#   Stored in directory: /root/.cache/pip/wheels/f8/6c/02/92ebc97f3b99ad5bfc675be2c513f9cb3504fdbe338314f377
#   Building wheel for pygtrie (setup.py) ... done
#   Created wheel for pygtrie: filename=pygtrie-2.4.2-py3-none-any.whl size=19062 sha256=a41e6c5bde307bb101ea36ae315326e8bae7af53ce810052ea805a8cfdde8fd0
#   Stored in directory: /root/.cache/pip/wheels/d3/f8/ba/1d828b1603ea422686eb694253a43cb3a5901ea4696c1e0603
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26324 sha256=0f4da364117d8aee177b192cf4ae1d5084b37c40377f30760c1ab832916caaea
#   Stored in directory: /root/.cache/pip/wheels/35/f3/15/01aa6571f0a72ee6ae7b827c1491c37a1f72d686fd22b43b0e
#   Building wheel for iso-639 (setup.py) ... done
#   Created wheel for iso-639: filename=iso_639-0.4.5-py3-none-any.whl size=169061 sha256=d5d9f95bdf659e34dc58e5faccd8256df5f79233faf4a3022b32190f41d61bae
#   Stored in directory: /root/.cache/pip/wheels/47/60/19/6d020fc92138ed1b113a18271e83ea4b5525fe770cb45b9a2e
#   Building wheel for odictliteral (setup.py) ... done
#   Created wheel for odictliteral: filename=odictliteral-1.0.0-py3-none-any.whl size=3122 sha256=f2c3583790eb1c72ebe667bd2df12858b70d223ab3a9eb6c8611cd8c2359dcc5
#   Stored in directory: /root/.cache/pip/wheels/3f/25/10/2ce4f3d7e604b790796f487e5e77a90b544eb2302d0ace109b
#   Building wheel for pycountry (setup.py) ... done
#   Created wheel for pycountry: filename=pycountry-20.7.3-py2.py3-none-any.whl size=10746883 sha256=b94c19b1e23294f8238a136b99843e87ea978e4f19dbad06b9b7ff2114821286
#   Stored in directory: /root/.cache/pip/wheels/57/e8/3f/120ccc1ff7541c108bc5d656e2a14c39da0d824653b62284c6
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=121000 sha256=132a9db01f79b449464d33cf3c7a8a4a7d6f33cbfea2a018e4740d61209b33fc
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
# Successfully built cytoolz ftfy langdetect langid mgzip msgpack-python pygtrie typing iso-639 odictliteral pycountry sentence-transformers
# Installing collected packages: isodate, rdflib, pyyaml, lml, typing, tokenizers, texttable, sacremoses, pyexcel-io, ply, pandas, owlrl, openpyxl, huggingface-hub, distro, ujson, typed-ast, transformers, tabula-py, SPARQLWrapper, sentencepiece, rdflib-jsonld, pyshacl, pyrallel.lib, pygtrie, pyexcel-xlsx, pyexcel-xls, pyexcel, mypy-extensions, msgpack-python, msgpack-numpy, langid, langdetect, jsonpath-ng, ftfy, deprecated, dateparser, cytoolz, cssselect, torchbiggraph, simplejson, shortuuid, sh, sentence-transformers, rltk, rfc3986, redis, pycountry, parsley, odictliteral, mypy, mgzip, lz4, loguru, iso-639, etk, kgtk
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 2.5.9
#     Uninstalling openpyxl-2.5.9:
#       Successfully uninstalled openpyxl-2.5.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.4 which is incompatible.
# Successfully installed SPARQLWrapper-1.8.5 cssselect-1.1.0 cytoolz-0.11.2 dateparser-1.1.0 deprecated-1.2.13 distro-1.6.0 etk-2.2.8 ftfy-6.0.3 huggingface-hub-0.1.2 iso-639-0.4.5 isodate-0.6.0 jsonpath-ng-1.5.3 kgtk-1.0.1 langdetect-1.0.9 langid-1.1.6 lml-0.1.0 loguru-0.5.3 lz4-3.1.3 mgzip-0.2.1 msgpack-numpy-0.4.3.2 msgpack-python-0.5.6 mypy-0.910 mypy-extensions-0.4.3 odictliteral-1.0.0 openpyxl-3.0.9 owlrl-5.2.3 pandas-1.3.4 parsley-1.3 ply-3.11 pycountry-20.7.3 pyexcel-0.6.7 pyexcel-io-0.6.5 pyexcel-xls-0.7.0 pyexcel-xlsx-0.6.0 pygtrie-2.4.2 pyrallel.lib-0.0.9 pyshacl-0.17.2 pyyaml-6.0 rdflib-6.0.2 rdflib-jsonld-0.6.2 redis-4.0.1 rfc3986-1.5.0 rltk-2.0.0a20 sacremoses-0.0.46 sentence-transformers-2.1.0 sentencepiece-0.1.96 sh-1.14.2 shortuuid-1.0.8 simplejson-3.17.6 tabula-py-2.3.0 texttable-1.6.4 tokenizers-0.10.3 torchbiggraph-1.0.0 transformers-4.12.5 typed-ast-1.4.3 typing-3.7.4.3 ujson-4.2.0

# %% [markdown]
# # KGTK Browser
#
# Builds a sqlite database for the graph and spawns a browser.

# %% [markdown]
# ## Clone the kgtk-browser repository and install the requirements

# %%
# Get the latest kgtk-browser from GitHub
# !rm -rf kgtk-browser && git clone https://github.com/usc-isi-i2/kgtk-browser

# Install the requirements (i.e. kgtk)
# !pip install -r kgtk-browser/requirements.txt
# Out:
# Cloning into 'kgtk-browser'...
# remote: Enumerating objects: 2070, done.
# remote: Counting objects: 100% (788/788), done.
# remote: Compressing objects: 100% (236/236), done.
# remote: Total 2070 (delta 605), reused 617 (delta 537), pack-reused 1282
# Receiving objects: 100% (2070/2070), 2.10 MiB | 6.70 MiB/s, done.
# Resolving deltas: 100% (1371/1371), done.
# Collecting Flask==2.0.1
#   Downloading Flask-2.0.1-py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.1 MB/s
# Requirement already satisfied: kgtk==1.0.1 in /usr/local/lib/python3.7/dist-packages (from -r kgtk-browser/requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: click>=7.1.2 in /usr/local/lib/python3.7/dist-packages (from Flask==2.0.1->-r kgtk-browser/requirements.txt (line 1)) (7.1.2)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Jinja2>=3.0
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 64.3 MB/s
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 56.0 MB/s
# Requirement already satisfied: lz4 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (3.1.3)
# Requirement already satisfied: etk>=2.2.8 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.2.8)
# Requirement already satisfied: rdflib-jsonld>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.6.2)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (7.4.0)
# Requirement already satisfied: parsley>=1.3 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.3)
# Requirement already satisfied: rltk in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.0.0a20)
# Requirement already satisfied: sh>=1.13 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.14.2)
# Requirement already satisfied: mgzip>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.2.1)
# Requirement already satisfied: pyrallel.lib==0.0.9 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.0.9)
# Requirement already satisfied: torchbiggraph in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: mypy in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.910)
# Requirement already satisfied: rdflib>=6.0.2 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: shortuuid in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.0.8)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (21.2.0)
# Requirement already satisfied: plac==1.1.3 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.1.3)
# Requirement already satisfied: iso-639 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.4.5)
# Requirement already satisfied: odictliteral in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (3.17.6)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.0)
# Requirement already satisfied: SPARQLWrapper in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.8.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (4.62.3)
# Requirement already satisfied: rfc3986 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: loguru in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: pycountry in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (20.7.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.11.2)
# Requirement already satisfied: dill>=0.3.2 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.3.4)
# Requirement already satisfied: pyshacl>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.17.2)
# Requirement already satisfied: redis in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (4.0.1)
# Requirement already satisfied: multiprocess>=0.70 in /usr/local/lib/python3.7/dist-packages (from pyrallel.lib==0.0.9->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.70.12.2)
# Requirement already satisfied: typing>=3.6 in /usr/local/lib/python3.7/dist-packages (from pyrallel.lib==0.0.9->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (3.7.4.3)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: srsly<1.1.0,>=0.0.6 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (3.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.0.6)
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.19.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.0.9 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.8.2)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->thinc==7.4.0->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (4.8.2)
# Requirement already satisfied: pyparsing>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: dateparser>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.7.2 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pygtrie>=2.2 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.4.2)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2018.9)
# Requirement already satisfied: wrapt>=1.10.11 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.13.3)
# Requirement already satisfied: pathlib>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: jdcal>=1.3 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: ftfy>=4.4.3 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.3.4)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (4.6.3)
# Requirement already satisfied: msgpack-python>=0.5.4 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.5.6)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.11.2)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: urllib3>=1.22 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: lml>=0.0.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.1.0)
# Requirement already satisfied: pyexcel>=0.5.7 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.6.7)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.2.5)
# Requirement already satisfied: pyexcel-xlsx>=0.5.6 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: idna>=2.6 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.10)
# Requirement already satisfied: cytoolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.11.2)
# Requirement already satisfied: pyexcel-io>=0.5.6 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.6.5)
# Requirement already satisfied: decorator>=4.2.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (4.4.2)
# Requirement already satisfied: msgpack-numpy<0.4.4.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.4.3.2)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.23.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: cssselect>=1.0.3 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: html5lib>=1.0b8 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: lxml>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (4.2.6)
# Requirement already satisfied: ply>=3.11 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (3.11)
# Requirement already satisfied: langid>=1.1.6 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.1.6)
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: tabula-py>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: chardet>=3.0.4 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: spacy==2.2.4 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.2.4)
# Requirement already satisfied: jsonpath-ng>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: ujson>=1.35 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (4.2.0)
# Requirement already satisfied: pyexcel-xls>=0.5.6 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: tzlocal>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: langdetect>=1.0.7 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.4->etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (57.4.0)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.7/dist-packages (from dateparser>=0.7.0->etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2019.12.20)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from html5lib>=1.0b8->etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->thinc==7.4.0->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->thinc==7.4.0->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (3.10.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=3.0->Flask==2.0.1->-r kgtk-browser/requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: msgpack>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from msgpack-numpy<0.4.4.0->etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.0.2)
# Requirement already satisfied: texttable>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from pyexcel>=0.5.7->etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.6.4)
# Requirement already satisfied: xlwt in /usr/local/lib/python3.7/dist-packages (from pyexcel-xls>=0.5.6->etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (from pyexcel-xls>=0.5.6->etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: openpyxl>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pyexcel-xlsx>=0.5.6->etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.6.1->pyexcel-xlsx>=0.5.6->etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: owlrl<6.0.0,>=5.2.3 in /usr/local/lib/python3.7/dist-packages (from pyshacl>=0.17.1->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (5.2.3)
# Requirement already satisfied: prettytable<3.0.0,>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from pyshacl>=0.17.1->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2021.10.8)
# Requirement already satisfied: distro in /usr/local/lib/python3.7/dist-packages (from tabula-py>=1.4.3->etk>=2.2.8->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from mypy->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.10.2)
# Requirement already satisfied: typed-ast<1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from mypy->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.4.3)
# Requirement already satisfied: mypy-extensions<0.5.0,>=0.4.3 in /usr/local/lib/python3.7/dist-packages (from mypy->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.7/dist-packages (from redis->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.2.13)
# Requirement already satisfied: distributed>=1.23 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.25.3)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (3.2.2)
# Requirement already satisfied: Cython>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.29.24)
# Requirement already satisfied: dask>=0.19.2 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.12.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: tblib in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (6.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: tornado>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (5.1.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (5.4.8)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.0.0->rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.0.0->rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=1.23->rltk->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (3.2.5)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (4.12.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.1.96)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.11.1+cu111)
# Requirement already satisfied: tokenizers>=0.10.3 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.10.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (0.0.46)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (21.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: h5py>=2.8 in /usr/local/lib/python3.7/dist-packages (from torchbiggraph->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.8->torchbiggraph->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (1.5.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers->kgtk==1.0.1->-r kgtk-browser/requirements.txt (line 2)) (7.1.2)
# Installing collected packages: Werkzeug, Jinja2, itsdangerous, Flask
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: Flask
#     Found existing installation: Flask 1.1.4
#     Uninstalling Flask-1.1.4:
#       Successfully uninstalled Flask-1.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.4 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed Flask-2.0.1 Jinja2-3.0.3 Werkzeug-2.0.2 itsdangerous-2.0.1

# %%
from kgtk.functions import kgtk, kypher
from kgtk.configure_kgtk_notebooks import ConfigureKGTK
import json
import os, sqlite3
from google.colab.output import eval_js

# %%
extra_files_config = {
    "claims": "claims.tsv.gz", 
    "labels": "labels.tsv.gz",
    "aliases": "aliases.tsv.gz", 
    "descriptions": "descriptions.tsv.gz",
    "qualifiers": "qualifiers.tsv.gz",
    "metadata": "metadata.tsv.gz"
}

open('/tmp/extra_files.json', 'w').write(json.dumps(extra_files_config))
# Out:
# 188

# %%
files = ['claims', 'labels', 'aliases', 'descriptions', 'qualifiers', 'metadata']

input_files_url="https://github.com/usc-isi-i2/kgtk-tutorial-files/raw/main/datasets/kgtk-browser"

input_path = None
output_path = '/tmp/projects'
project_name = 'kgtk-browser'


# Minimal KGTK configuration for this example
ck = ConfigureKGTK(files, input_files_url=input_files_url)
ck.configure_kgtk(input_graph_path=input_path,
                  output_path=output_path,
                  project_name=project_name,
                  json_config_file = '/tmp/extra_files.json',
                  graph_cache_path='./wikidata.sqlite3.db'
                  )
# Out:
# User home: /root
# Current dir: /content
# KGTK dir: /
# Use-cases dir: //use-cases
# --2021-11-18 21:09:49--  https://github.com/usc-isi-i2/kgtk-tutorial-files/raw/main/datasets/kgtk-browser/claims.tsv.gz
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/usc-isi-i2/kgtk-notebooks/raw/main/datasets/kgtk-browser/claims.tsv.gz [following]
# --2021-11-18 21:09:49--  https://github.com/usc-isi-i2/kgtk-notebooks/raw/main/datasets/kgtk-browser/claims.tsv.gz
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/usc-isi-i2/kgtk-notebooks/main/datasets/kgtk-browser/claims.tsv.gz [following]
# --2021-11-18 21:09:49--  https://raw.githubusercontent.com/usc-isi-i2/kgtk-notebooks/main/datasets/kgtk-browser/claims.tsv.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32763831 (31M) [application/octet-stream]
# Saving to: ‘/root/isi-kgtk-tutorial/input/claims.tsv.gz’
#
#      0K .......... .......... .......... .......... ..........  0% 6.88M 5s
#     50K .......... .......... .......... .......... ..........  0% 6.65M 5s
#    100K .......... .......... .......... .......... ..........  0% 31.0M 3s
#    150K .......... .......... .......... .......... ..........  0% 37.8M 3s
#    200K .......... .......... .......... .......... ..........  0% 10.5M 3s
#    250K .......... .......... .......... .......... ..........  0% 46.3M 2s
#    300K .......... .......... .......... .......... ..........  1% 39.7M 2s
#    350K .......... .......... .......... .......... ..........  1% 74.1M 2s
#    400K .......... .......... .......... .......... ..........  1% 58.4M 2s
#    450K .......... .......... .......... .......... ..........  1%  135M 2s
#    500K .......... .......... .......... .......... ..........  1% 15.1M 2s
#    550K .......... .......... .......... .......... ..........  1% 38.4M 2s
#    600K .......... .......... .......... .......... ..........  2% 40.4M 2s
#    650K .......... .......... .......... .......... ..........  2% 77.7M 1s
#    700K .......... .......... .......... .......... ..........  2% 85.4M 1s
#    750K .......... .......... .......... .......... ..........  2% 56.4M 1s
#    800K .......... .......... .......... .......... ..........  2%  137M 1s
#    850K .......... .......... .......... .......... ..........  2%  130M 1s
#    900K .......... .......... .......... .......... ..........  2% 76.1M 1s
#    950K .......... .......... .......... .......... ..........  3% 73.4M 1s
#   1000K .......... .......... .......... .......... ..........  3%  120M 1s
#   8000K .......... .......... .......... .......... .......... 97%  177M 0s
#   8050K .......... .......... .......... .......... .......... 97%  165M 0s
#   8100K .......... .......... .......... .......... .......... 98%  187M 0s
#   8150K .......... .......... .......... .......... .......... 98%  171M 0s
#   8200K .......... .......... .......... .......... .......... 99%  147M 0s
#   8250K .......... .......... .......... .......... ....      100%  196M=0.08s
#
# 2021-11-18 21:09:56 (97.3 MB/s) - ‘/root/isi-kgtk-tutorial/input/qualifiers.tsv.gz’ saved [8494027/8494027]
#
# --2021-11-18 21:09:56--  https://github.com/usc-isi-i2/kgtk-tutorial-files/raw/main/datasets/kgtk-browser/metadata.tsv.gz
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/usc-isi-i2/kgtk-notebooks/raw/main/datasets/kgtk-browser/metadata.tsv.gz [following]
# --2021-11-18 21:09:57--  https://github.com/usc-isi-i2/kgtk-notebooks/raw/main/datasets/kgtk-browser/metadata.tsv.gz
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/usc-isi-i2/kgtk-notebooks/main/datasets/kgtk-browser/metadata.tsv.gz [following]
# --2021-11-18 21:09:57--  https://raw.githubusercontent.com/usc-isi-i2/kgtk-notebooks/main/datasets/kgtk-browser/metadata.tsv.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21191 (21K) [application/octet-stream]
# Saving to: ‘/root/isi-kgtk-tutorial/input/metadata.tsv.gz’
#
#      0K .......... ..........                                 100% 47.7M=0s
#
# 2021-11-18 21:09:57 (47.7 MB/s) - ‘/root/isi-kgtk-tutorial/input/metadata.tsv.gz’ saved [21191/21191]

# %%
# Review all of the environment variables used:

ck.print_env_variables()
# Out:
# USE_CASES_DIR: //use-cases
# TEMP: /tmp/projects/kgtk-browser/temp.kgtk-browser
# STORE: ./wikidata.sqlite3.db
# kypher: kgtk query --graph-cache ./wikidata.sqlite3.db
# KGTK_GRAPH_CACHE: ./wikidata.sqlite3.db
# KGTK_OPTION_DEBUG: false
# EXAMPLES_DIR: //examples
# KGTK_LABEL_FILE: /root/isi-kgtk-tutorial/input/labels.en.tsv.gz
# GRAPH: /root/isi-kgtk-tutorial/input
# OUT: /tmp/projects/kgtk-browser
# kgtk: kgtk
# claims: /root/isi-kgtk-tutorial/input/claims.tsv.gz
# labels: /root/isi-kgtk-tutorial/input/labels.tsv.gz
# aliases: /root/isi-kgtk-tutorial/input/aliases.tsv.gz
# descriptions: /root/isi-kgtk-tutorial/input/descriptions.tsv.gz
# qualifiers: /root/isi-kgtk-tutorial/input/qualifiers.tsv.gz
# metadata: /root/isi-kgtk-tutorial/input/metadata.tsv.gz

# %%
ck.load_files_into_cache()
# Out:
# kgtk query --graph-cache ./wikidata.sqlite3.db -i "/root/isi-kgtk-tutorial/input/claims.tsv.gz" --as claims  -i "/root/isi-kgtk-tutorial/input/labels.tsv.gz" --as labels  -i "/root/isi-kgtk-tutorial/input/aliases.tsv.gz" --as aliases  -i "/root/isi-kgtk-tutorial/input/descriptions.tsv.gz" --as descriptions  -i "/root/isi-kgtk-tutorial/input/qualifiers.tsv.gz" --as qualifiers  -i "/root/isi-kgtk-tutorial/input/metadata.tsv.gz" --as metadata  --limit 3
# node1	label	node2	id
# P10	P31	Q18610173	P10-P31-Q18610173-85ef4d24-0
# P10	Pdirected_pagerank	2.2996980087906936e-06	P10-Pdirected_pagerank-2
# P10	Pout_degree	1	P10-Pout_degree-6b86b2

# %%
conn = sqlite3.connect(os.environ['STORE'])

# %% [markdown]
# ## Create columns and indices required for the search
#
# Creates indices and the other columns required for text search feature in the browser.

# %% [markdown]
# Usando o FTS5 do SQLite

# %%
#  Build the "node1;upper" column in the label table
conn.execute('ALTER TABLE graph_2 ADD COLUMN "node1;upper" text')
conn.commit()

conn.execute('UPDATE graph_2 SET "node1;upper" = upper(node1)')
conn.commit()

# Index the node1;upper column. It supports case-insensitive searches on item labels
conn.execute('CREATE INDEX "graph_2_node1upper_idx" on graph_2 ("node1;upper")')
conn.commit()

conn.execute('ANALYZE "graph_2_node1upper_idx"')
conn.commit()

# Build the "node2;upper" column in the label table
conn.execute('ALTER TABLE graph_2 ADD COLUMN "node2;upper" text')
conn.commit()

conn.execute('UPDATE graph_2 SET "node2;upper" = upper(node2)')
conn.commit()

# Index the node2;upper column. It supports case-insensitive searches on item labels
conn.execute('CREATE INDEX "graph_2_node2upper_idx" on graph_2 ("node2;upper")')
conn.commit()

conn.execute('ANALYZE "graph_2_node2upper_idx"')
conn.commit()

# %% [markdown]
# ### Verify that the graph cache has loaded as expected

# %%
kgtk("""
  query --show-cache \
    --graph-cache ${STORE}
""")
# Out:
# Graph Cache:
# DB file: ./wikidata.sqlite3.db
#   size:  184.95 MB   	free:  0 Bytes   	modified:  2021-11-18 21:11:15
#
# KGTK File Information:
# aliases:
#   size:  1.28 MB   	modified:  2021-11-18 21:09:54   	graph:  graph_3
# claims:
#   size:  31.25 MB   	modified:  2021-11-18 21:09:52   	graph:  graph_1
# descriptions:
#   size:  1.28 MB   	modified:  2021-11-18 21:09:55   	graph:  graph_4
# labels:
#   size:  1.02 MB   	modified:  2021-11-18 21:09:53   	graph:  graph_2
# metadata:
#   size:  20.69 KB   	modified:  2021-11-18 21:09:57   	graph:  graph_6
# qualifiers:
#   size:  8.10 MB   	modified:  2021-11-18 21:09:56   	graph:  graph_5
#
# Graph Table Information:
# graph_1:
#   size:  118.56 MB   	created:  2021-11-18 21:10:21
#   header:  ['node1', 'label', 'node2', 'id']
# graph_2:
#   size:  4.09 MB   	created:  2021-11-18 21:10:22
#   header:  ['node1', 'label', 'node2', 'id']
# graph_3:
#   size:  5.27 MB   	created:  2021-11-18 21:10:22
#   header:  ['node1', 'label', 'node2', 'id']
# graph_4:
#   size:  5.80 MB   	created:  2021-11-18 21:10:22
#   header:  ['node1', 'label', 'node2', 'id']
# graph_5:
#   size:  45.25 MB   	created:  2021-11-18 21:10:26
#   header:  ['node1', 'label', 'node2', 'id']
# graph_6:
#   size:  184.00 KB   	created:  2021-11-18 21:10:26
#   header:  ['node1', 'label', 'node2', 'id']

# %% [markdown]
# ## Running the kgtk-browser app!

# %% [markdown]
# ### Run this cell, it will print the URL to KGTK Browser running on Google Colab VM.
#
# **Note**: Please run the next cell before clicking on the printed link

# %%
# Get a unique link pointing to this google colab environment

print(eval_js("google.colab.kernel.proxyPort(8000)") + "browser")
# Out:
# https://eelzbmzjg1e-496ff2e9c6d22116-8000-colab.googleusercontent.com/browser

# %% [markdown]
# ### RUN the backend for KGTK Browser
# This cell will keep running until you interrupt runtime, `Runtime -> Interrupt execution` from the menu.

# %%
# Set the environment variables for flask
os.environ['FLASK_ENV'] = 'production'
os.environ['FLASK_APP'] = 'kgtk-browser/kgtk_browser_app.py'
os.environ['KGTK_BROWSER_CONFIG'] = 'kgtk_browser_config.py'

# Run the kgtk-browser app
# !flask run --port 8000
# Out:
#  * Serving Flask app 'kgtk-browser/kgtk_browser_app.py' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# [2021-11-18 21:12:28 query]: SQL Translation:
# ---------------------------------------------
#   SELECT DISTINCT graph_2_c1."node1" "_aLias.node1", graph_2_c1."node2" "_aLias.node_label"
#      FROM graph_2 AS graph_2_c1
#      WHERE graph_2_c1."label" = ?
#         AND ((graph_2_c1."node1" = ?) AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c1."node2") = ?)))
#      LIMIT ?
#   PARAS: ['label', ('NODE',), ('LANG',), 'any', ('LANG',), 10000]
# ---------------------------------------------
# [2021-11-18 21:12:28 sqlstore]: CREATE INDEX "graph_2_label_idx" ON "graph_2" ("label")
# [2021-11-18 21:12:28 sqlstore]: ANALYZE "graph_2_label_idx"
# [2021-11-18 21:12:28 query]: SQL Translation:
# ---------------------------------------------
#   SELECT DISTINCT graph_3_c1."node1" "_aLias.node1", graph_3_c1."node2" "_aLias.node_alias"
#      FROM graph_3 AS graph_3_c1
#      WHERE graph_3_c1."label" = ?
#         AND ((graph_3_c1."node1" = ?) AND ((? = ?) OR (kgtk_lqstring_lang(graph_3_c1."node2") = ?)))
#      LIMIT ?
#   PARAS: ['alias', ('NODE',), ('LANG',), 'any', ('LANG',), 10000]
# ---------------------------------------------
# [2021-11-18 21:12:28 sqlstore]: CREATE INDEX "graph_3_label_idx" ON "graph_3" ("label")
# [2021-11-18 21:12:28 sqlstore]: ANALYZE "graph_3_label_idx"
# [2021-11-18 21:12:28 query]: SQL Translation:
# ---------------------------------------------
#   SELECT DISTINCT graph_4_c1."node1" "_aLias.node1", graph_4_c1."node2" "_aLias.node_description"
#      FROM graph_4 AS graph_4_c1
#      WHERE graph_4_c1."label" = ?
#         AND ((graph_4_c1."node1" = ?) AND ((? = ?) OR (kgtk_lqstring_lang(graph_4_c1."node2") = ?)))
#      LIMIT ?
#   PARAS: ['description', ('NODE',), ('LANG',), 'any', ('LANG',), 10000]
# ---------------------------------------------
# [2021-11-18 21:12:28 sqlstore]: CREATE INDEX "graph_4_label_idx" ON "graph_4" ("label")
# [2021-11-18 21:12:28 sqlstore]: ANALYZE "graph_4_label_idx"
# [2021-11-18 21:12:28 query]: SQL Translation:
# ---------------------------------------------
#   SELECT DISTINCT graph_1_c1."node1" "_aLias.node1", graph_1_c1."node2" "_aLias.node_image"
#      FROM graph_1 AS graph_1_c1
#      WHERE graph_1_c1."label" = ?
#         AND (graph_1_c1."node1" = ?)
#      LIMIT ?
#   PARAS: ['P18', ('NODE',), 10000]
# ---------------------------------------------
# [2021-11-18 21:12:28 sqlstore]: CREATE INDEX "graph_1_label_idx" ON "graph_1" ("label")
# [2021-11-18 21:12:30 sqlstore]: ANALYZE "graph_1_label_idx"
# [2021-11-18 21:12:31 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id" "_aLias.id", graph_1_c1."node1" "_aLias.node1", graph_1_c1."label" "_aLias.label", graph_1_c1."node2" "_aLias.node2", graph_2_c2."node2" "_aLias.node_label", graph_1_c3."node2" "_aLias.node_image", graph_6_c4."node2" "_aLias.node_fanout"
#      FROM graph_1 AS graph_1_c1
#      LEFT JOIN graph_2 AS graph_2_c2
#      ON graph_1_c1."node2" = graph_2_c2."node1"
#         AND graph_2_c2."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c2."node2") = ?))
#      LEFT JOIN graph_1 AS graph_1_c3
#      ON graph_1_c1."node2" = graph_1_c3."node1"
#         AND graph_1_c3."label" = ?
#         AND ?
#      LEFT JOIN graph_6 AS graph_6_c4
#      ON graph_1_c1."node2" = graph_6_c4."node1"
#         AND graph_6_c4."label" = ?
#         AND ?
#      WHERE (graph_1_c1."node1" = ?)
#      LIMIT ?
#   PARAS: ['label', ('LANG',), 'any', ('LANG',), 'P18', ('FETCH_IMAGES',), 'count_distinct_properties', ('FETCH_FANOUTS',), ('NODE',), 10000]
# ---------------------------------------------
# [2021-11-18 21:12:31 sqlstore]: CREATE INDEX "graph_2_node1_idx" ON "graph_2" ("node1")
# [2021-11-18 21:12:31 sqlstore]: ANALYZE "graph_2_node1_idx"
# [2021-11-18 21:12:31 sqlstore]: CREATE INDEX "graph_1_node2_idx" ON "graph_1" ("node2")
# [2021-11-18 21:12:34 sqlstore]: ANALYZE "graph_1_node2_idx"
# [2021-11-18 21:12:34 sqlstore]: CREATE INDEX "graph_1_node1_idx" ON "graph_1" ("node1")
# [2021-11-18 21:12:35 sqlstore]: ANALYZE "graph_1_node1_idx"
# [2021-11-18 21:12:35 sqlstore]: CREATE INDEX "graph_6_node1_idx" ON "graph_6" ("node1")
# [2021-11-18 21:12:35 sqlstore]: ANALYZE "graph_6_node1_idx"
# [2021-11-18 21:12:35 sqlstore]: CREATE INDEX "graph_6_label_idx" ON "graph_6" ("label")
# [2021-11-18 21:12:35 sqlstore]: ANALYZE "graph_6_label_idx"
# [2021-11-18 21:12:36 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id" "_aLias.id", graph_1_c1."node1" "_aLias.node1", graph_1_c1."label" "_aLias.label", graph_1_c1."node2" "_aLias.node2", graph_2_c2."node2" "_aLias.node_label", graph_1_c3."node2" "_aLias.node_image", graph_6_c4."node2" "_aLias.node_fanout"
#      FROM graph_1 AS graph_1_c1
#      LEFT JOIN graph_2 AS graph_2_c2
#      ON graph_1_c1."node1" = graph_2_c2."node1"
#         AND graph_2_c2."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c2."node2") = ?))
#      LEFT JOIN graph_1 AS graph_1_c3
#      ON graph_1_c1."node1" = graph_1_c3."node1"
#         AND graph_1_c3."label" = ?
#         AND ?
#      LEFT JOIN graph_6 AS graph_6_c4
#      ON graph_1_c1."node1" = graph_6_c4."node1"
#         AND graph_6_c4."label" = ?
#         AND ?
#      WHERE (graph_1_c1."node2" = ?)
#      LIMIT ?
#   PARAS: ['label', ('LANG',), 'any', ('LANG',), 'P18', ('FETCH_IMAGES',), 'count_distinct_properties', ('FETCH_FANOUTS',), ('NODE',), 10000]
# ---------------------------------------------
# [2021-11-18 21:12:36 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_5_c2."id", graph_1_c1."id" "_aLias.node1", graph_5_c2."label" "_aLias.label", graph_5_c2."node2" "_aLias.node2", graph_2_c3."node2" "_aLias.node_label", graph_1_c4."node2" "_aLias.node_image", graph_6_c5."node2" "_aLias.node_fanout"
#      FROM graph_1 AS graph_1_c1
#      INNER JOIN graph_5 AS graph_5_c2
#      ON graph_1_c1."id" = graph_5_c2."node1"
#         AND (graph_1_c1."node1" = ?)
#      LEFT JOIN graph_2 AS graph_2_c3
#      ON graph_5_c2."node2" = graph_2_c3."node1"
#         AND graph_2_c3."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c3."node2") = ?))
#      LEFT JOIN graph_1 AS graph_1_c4
#      ON graph_5_c2."node2" = graph_1_c4."node1"
#         AND graph_1_c4."label" = ?
#         AND ?
#      LEFT JOIN graph_6 AS graph_6_c5
#      ON graph_5_c2."node2" = graph_6_c5."node1"
#         AND graph_6_c5."label" = ?
#         AND ?
#      ORDER BY graph_1_c1."id" ASC, graph_5_c2."node2" DESC
#      LIMIT ?
#   PARAS: [('NODE',), 'label', ('LANG',), 'any', ('LANG',), 'P18', ('FETCH_IMAGES',), 'count_distinct_properties', ('FETCH_FANOUTS',), 10000]
# ---------------------------------------------
# [2021-11-18 21:12:36 sqlstore]: CREATE INDEX "graph_1_id_idx" ON "graph_1" ("id")
# [2021-11-18 21:12:39 sqlstore]: ANALYZE "graph_1_id_idx"
# [2021-11-18 21:12:39 sqlstore]: CREATE INDEX "graph_5_node2_idx" ON "graph_5" ("node2")
# [2021-11-18 21:12:40 sqlstore]: ANALYZE "graph_5_node2_idx"
# [2021-11-18 21:12:40 sqlstore]: CREATE INDEX "graph_5_node1_idx" ON "graph_5" ("node1")
# [2021-11-18 21:12:40 sqlstore]: ANALYZE "graph_5_node1_idx"
# [2021-11-18 21:12:41 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_5_c2."id", graph_1_c1."id" "_aLias.node1", graph_5_c2."label" "_aLias.label", graph_5_c2."node2" "_aLias.node2", graph_2_c3."node2" "_aLias.node_label", graph_1_c4."node2" "_aLias.node_image", graph_6_c5."node2" "_aLias.node_fanout"
#      FROM graph_1 AS graph_1_c1
#      INNER JOIN graph_5 AS graph_5_c2
#      ON graph_1_c1."id" = graph_5_c2."node1"
#         AND (graph_1_c1."node2" = ?)
#      LEFT JOIN graph_2 AS graph_2_c3
#      ON graph_5_c2."node2" = graph_2_c3."node1"
#         AND graph_2_c3."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c3."node2") = ?))
#      LEFT JOIN graph_1 AS graph_1_c4
#      ON graph_5_c2."node2" = graph_1_c4."node1"
#         AND graph_1_c4."label" = ?
#         AND ?
#      LEFT JOIN graph_6 AS graph_6_c5
#      ON graph_5_c2."node2" = graph_6_c5."node1"
#         AND graph_6_c5."label" = ?
#         AND ?
#      ORDER BY graph_1_c1."id" ASC, graph_5_c2."node2" DESC
#      LIMIT ?
#   PARAS: [('NODE',), 'label', ('LANG',), 'any', ('LANG',), 'P18', ('FETCH_IMAGES',), 'count_distinct_properties', ('FETCH_FANOUTS',), 10000]
# ---------------------------------------------
# [2021-11-18 21:12:41 query]: SQL Translation:
# ---------------------------------------------
#   SELECT DISTINCT graph_2_c1."node1" "_aLias.node1", graph_2_c1."node2" "_aLias.node_label"
#      FROM graph_2 AS graph_2_c1
#      WHERE graph_2_c1."label" = ?
#         AND graph_2_c1."node1;upper" = graph_2_c1."node1;upper"
#         AND ((graph_2_c1."node1;upper" = ?) AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c1."node2") = ?)))
#      LIMIT ?
#   PARAS: ['label', ('NODE',), ('LANG',), 'any', ('LANG',), 10000]
# ---------------------------------------------
# [2021-11-18 21:12:41 query]: SQL Translation:
# ---------------------------------------------
#   SELECT DISTINCT graph_2_c1."node1" "_aLias.node1", graph_2_c1."node2" "_aLias.node_label"
#      FROM graph_2 AS graph_2_c1
#      WHERE graph_2_c1."label" = ?
#         AND ((graph_2_c1."node2" = ?) AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c1."node2") = ?)))
#      LIMIT ?
#   PARAS: ['label', ('LABEL',), ('LANG',), 'any', ('LANG',), 10000]
# ---------------------------------------------
# [2021-11-18 21:12:41 query]: SQL Translation:
# ---------------------------------------------
#   SELECT DISTINCT graph_2_c1."node1" "_aLias.node1", graph_2_c1."node2" "_aLias.node_label"
#      FROM graph_2 AS graph_2_c1
#      WHERE graph_2_c1."label" = ?
#         AND graph_2_c1."node2;upper" = graph_2_c1."node2;upper"
#         AND ((graph_2_c1."node2;upper" = ?) AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c1."node2") = ?)))
#      LIMIT ?
#   PARAS: ['label', ('LABEL',), ('LANG',), 'any', ('LANG',), 10000]
# ---------------------------------------------
# [2021-11-18 21:12:41 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_2_c1."node1" "_aLias.node1", graph_2_c1."node2" "_aLias.node_label"
#      FROM graph_2 AS graph_2_c1
#      WHERE graph_2_c1."label" = ?
#         AND (glob(?, graph_2_c1."node1") AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c1."node2") = ?)))
#      ORDER BY graph_2_c1."node1" ASC, graph_2_c1."node2" ASC
#      LIMIT ?
#   PARAS: ['label', ('NODE',), ('LANG',), 'any', ('LANG',), ('LIMIT',)]
# ---------------------------------------------
# [2021-11-18 21:12:41 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_2_c1."node1" "_aLias.node1", graph_2_c1."node2" "_aLias.node_label"
#      FROM graph_2 AS graph_2_c1
#      WHERE graph_2_c1."label" = ?
#         AND graph_2_c1."node1;upper" = graph_2_c1."node1;upper"
#         AND (glob(?, graph_2_c1."node1;upper") AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c1."node2") = ?)))
#      ORDER BY graph_2_c1."node1" ASC, graph_2_c1."node2" ASC
#      LIMIT ?
#   PARAS: ['label', ('NODE',), ('LANG',), 'any', ('LANG',), ('LIMIT',)]
# ---------------------------------------------
# [2021-11-18 21:12:41 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_2_c1."node1" "_aLias.node1", graph_2_c1."node2" "_aLias.node_label"
#      FROM graph_2 AS graph_2_c1
#      WHERE graph_2_c1."label" = ?
#         AND (glob(?, graph_2_c1."node2") AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c1."node2") = ?)))
#      LIMIT ?
#   PARAS: ['label', ('LABEL',), ('LANG',), 'any', ('LANG',), ('LIMIT',)]
# ---------------------------------------------
# [2021-11-18 21:12:41 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_2_c1."node1" "_aLias.node1", graph_2_c1."node2" "_aLias.node_label"
#      FROM graph_2 AS graph_2_c1
#      WHERE graph_2_c1."label" = ?
#         AND graph_2_c1."node2;upper" = graph_2_c1."node2;upper"
#         AND (glob(?, graph_2_c1."node2;upper") AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c1."node2") = ?)))
#      LIMIT ?
#   PARAS: ['label', ('LABEL',), ('LANG',), 'any', ('LANG',), ('LIMIT',)]
# ---------------------------------------------
# [2021-11-18 21:12:42 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id" "_aLias.id", graph_1_c1."node1" "_aLias.node1", graph_1_c1."label" "_aLias.relationship", graph_1_c1."node2" "_aLias.node2", graph_2_c2."node2" "_aLias.relationship_label", graph_1_c1."node2" "_aLias.target_node", graph_2_c3."node2" "_aLias.target_label", graph_4_c4."node2" "_aLias.target_description", graph_6_c5."node2" "_aLias.wikidatatype"
#      FROM graph_1 AS graph_1_c1
#      LEFT JOIN graph_2 AS graph_2_c2
#      ON graph_1_c1."label" = graph_2_c2."node1"
#         AND graph_2_c2."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c2."node2") = ?))
#      LEFT JOIN graph_2 AS graph_2_c3
#      ON graph_1_c1."node2" = graph_2_c3."node1"
#         AND graph_2_c3."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c3."node2") = ?))
#      LEFT JOIN graph_4 AS graph_4_c4
#      ON graph_1_c1."id" = graph_4_c4."id"
#         AND graph_1_c1."node2" = graph_4_c4."node1"
#         AND graph_4_c4."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_4_c4."node2") = ?))
#      LEFT JOIN graph_6 AS graph_6_c5
#      ON graph_1_c1."label" = graph_6_c5."node1"
#         AND graph_6_c5."label" = ?
#      WHERE graph_1_c1."label" = graph_1_c1."label"
#         AND (graph_1_c1."node1" = ?)
#      ORDER BY graph_1_c1."label" ASC, graph_1_c1."node2" ASC, graph_1_c1."id" ASC, graph_2_c2."node2" ASC, graph_2_c3."node2" ASC, graph_4_c4."node2" ASC
#      LIMIT ?
#   PARAS: ['label', ('LANG',), 'any', ('LANG',), 'label', ('LANG',), 'any', ('LANG',), 'description', ('LANG',), 'any', ('LANG',), 'datatype', ('NODE',), ('LIMIT',)]
# ---------------------------------------------
# [2021-11-18 21:12:42 sqlstore]: CREATE INDEX "graph_4_node1_idx" ON "graph_4" ("node1")
# [2021-11-18 21:12:42 sqlstore]: ANALYZE "graph_4_node1_idx"
# [2021-11-18 21:12:42 sqlstore]: CREATE INDEX "graph_4_id_idx" ON "graph_4" ("id")
# [2021-11-18 21:12:42 sqlstore]: ANALYZE "graph_4_id_idx"
# [2021-11-18 21:12:42 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id" "_aLias.id", graph_1_c1."node1" "_aLias.node1", graph_5_c2."id" "_aLias.qual_id", graph_5_c2."label" "_aLias.qual_relationship", graph_5_c2."node2" "_aLias.qual_node2", graph_2_c3."node2" "_aLias.qual_relationship_label", graph_2_c4."node2" "_aLias.qual_node2_label", graph_4_c5."node2" "_aLias.qual_node2_description"
#      FROM graph_1 AS graph_1_c1
#      INNER JOIN graph_5 AS graph_5_c2
#      ON graph_1_c1."id" = graph_5_c2."node1"
#         AND graph_5_c2."label" = graph_5_c2."label"
#         AND (graph_1_c1."node1" = ?)
#      LEFT JOIN graph_2 AS graph_2_c3
#      ON graph_5_c2."label" = graph_2_c3."node1"
#         AND graph_2_c3."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c3."node2") = ?))
#      LEFT JOIN graph_2 AS graph_2_c4
#      ON graph_5_c2."node2" = graph_2_c4."node1"
#         AND graph_2_c4."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c4."node2") = ?))
#      LEFT JOIN graph_4 AS graph_4_c5
#      ON graph_1_c1."id" = graph_4_c5."id"
#         AND graph_5_c2."node2" = graph_4_c5."node1"
#         AND graph_4_c5."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_4_c5."node2") = ?))
#      ORDER BY graph_1_c1."id" ASC, graph_5_c2."label" ASC, graph_5_c2."node2" ASC, graph_5_c2."id" ASC, graph_2_c3."node2" ASC, graph_2_c4."node2" ASC, graph_4_c5."node2" ASC
#      LIMIT ?
#   PARAS: [('NODE',), 'label', ('LANG',), 'any', ('LANG',), 'label', ('LANG',), 'any', ('LANG',), 'description', ('LANG',), 'any', ('LANG',), ('LIMIT',)]
# ---------------------------------------------
# [2021-11-18 21:12:42 sqlstore]: CREATE INDEX "graph_5_label_idx" ON "graph_5" ("label")
# [2021-11-18 21:12:42 sqlstore]: ANALYZE "graph_5_label_idx"
# [2021-11-18 21:12:43 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id" "_aLias.id", graph_1_c1."node1" "_aLias.node1", graph_5_c2."id" "_aLias.qual_id", graph_5_c2."label" "_aLias.qual_relationship", graph_5_c2."node2" "_aLias.qual_node2", graph_2_c3."node2" "_aLias.qual_relationship_label", graph_2_c4."node2" "_aLias.qual_node2_label", graph_4_c5."node2" "_aLias.qual_node2_description"
#      FROM graph_1 AS graph_1_c1
#      INNER JOIN graph_5 AS graph_5_c2
#      ON graph_1_c1."id" = graph_5_c2."node1"
#         AND graph_5_c2."label" = graph_5_c2."label"
#         AND (graph_1_c1."id" = ?)
#      LEFT JOIN graph_2 AS graph_2_c3
#      ON graph_5_c2."label" = graph_2_c3."node1"
#         AND graph_2_c3."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c3."node2") = ?))
#      LEFT JOIN graph_2 AS graph_2_c4
#      ON graph_5_c2."node2" = graph_2_c4."node1"
#         AND graph_2_c4."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c4."node2") = ?))
#      LEFT JOIN graph_4 AS graph_4_c5
#      ON graph_1_c1."id" = graph_4_c5."id"
#         AND graph_5_c2."node2" = graph_4_c5."node1"
#         AND graph_4_c5."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_4_c5."node2") = ?))
#      ORDER BY graph_1_c1."id" ASC, graph_5_c2."label" ASC, graph_5_c2."node2" ASC, graph_5_c2."id" ASC, graph_2_c3."node2" ASC, graph_2_c4."node2" ASC, graph_4_c5."node2" ASC
#      LIMIT ?
#   PARAS: [('EDGE_ID',), 'label', ('LANG',), 'any', ('LANG',), 'label', ('LANG',), 'any', ('LANG',), 'description', ('LANG',), 'any', ('LANG',), ('LIMIT',)]
# ---------------------------------------------
# [2021-11-18 21:12:43 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id" "_aLias.id", graph_1_c1."node1" "_aLias.node1", graph_1_c1."label" "_aLias.relationship", graph_1_c1."node2" "_aLias.node2", graph_2_c2."node2" "_aLias.relationship_label", graph_1_c1."node1" "_aLias.target_node", graph_2_c3."node2" "_aLias.target_label", graph_4_c4."node2" "_aLias.target_description", graph_6_c5."node2" "_aLias.wikidatatype"
#      FROM graph_1 AS graph_1_c1
#      LEFT JOIN graph_2 AS graph_2_c2
#      ON graph_1_c1."label" = graph_2_c2."node1"
#         AND graph_2_c2."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c2."node2") = ?))
#      LEFT JOIN graph_2 AS graph_2_c3
#      ON graph_1_c1."node1" = graph_2_c3."node1"
#         AND graph_2_c3."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c3."node2") = ?))
#      LEFT JOIN graph_4 AS graph_4_c4
#      ON graph_1_c1."id" = graph_4_c4."id"
#         AND graph_1_c1."node1" = graph_4_c4."node1"
#         AND graph_4_c4."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_4_c4."node2") = ?))
#      LEFT JOIN graph_6 AS graph_6_c5
#      ON graph_1_c1."label" = graph_6_c5."node1"
#         AND graph_6_c5."label" = ?
#      WHERE graph_1_c1."label" = graph_1_c1."label"
#         AND (graph_1_c1."node2" = ?)
#      ORDER BY graph_1_c1."label" ASC, graph_1_c1."node2" ASC, graph_1_c1."id" ASC, graph_2_c2."node2" ASC, graph_2_c3."node2" ASC, graph_4_c4."node2" ASC
#      LIMIT ?
#   PARAS: ['label', ('LANG',), 'any', ('LANG',), 'label', ('LANG',), 'any', ('LANG',), 'description', ('LANG',), 'any', ('LANG',), 'datatype', ('NODE',), 10000]
# ---------------------------------------------
# [2021-11-18 21:12:43 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."id" "_aLias.id", graph_1_c1."node1" "_aLias.node1", graph_5_c2."id" "_aLias.qual_id", graph_5_c2."label" "_aLias.qual_relationship", graph_5_c2."node2" "_aLias.qual_node2", graph_2_c3."node2" "_aLias.qual_relationship_label", graph_2_c4."node2" "_aLias.qual_node2_label", graph_4_c5."node2" "_aLias.qual_node2_description"
#      FROM graph_1 AS graph_1_c1
#      INNER JOIN graph_5 AS graph_5_c2
#      ON graph_1_c1."id" = graph_5_c2."node1"
#         AND graph_5_c2."label" = graph_5_c2."label"
#         AND (graph_1_c1."node2" = ?)
#      LEFT JOIN graph_2 AS graph_2_c3
#      ON graph_5_c2."label" = graph_2_c3."node1"
#         AND graph_2_c3."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c3."node2") = ?))
#      LEFT JOIN graph_2 AS graph_2_c4
#      ON graph_5_c2."node2" = graph_2_c4."node1"
#         AND graph_2_c4."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c4."node2") = ?))
#      LEFT JOIN graph_4 AS graph_4_c5
#      ON graph_1_c1."id" = graph_4_c5."id"
#         AND graph_5_c2."node2" = graph_4_c5."node1"
#         AND graph_4_c5."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_4_c5."node2") = ?))
#      ORDER BY graph_1_c1."id" ASC, graph_5_c2."label" ASC, graph_5_c2."node2" ASC, graph_5_c2."id" ASC, graph_2_c3."node2" ASC, graph_2_c4."node2" ASC, graph_4_c5."node2" ASC
#      LIMIT ?
#   PARAS: [('NODE',), 'label', ('LANG',), 'any', ('LANG',), 'label', ('LANG',), 'any', ('LANG',), 'description', ('LANG',), 'any', ('LANG',), 10000]
# ---------------------------------------------
# [2021-11-18 21:12:43 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."node1" "_aLias.node1", graph_2_c2."node2" "_aLias.node1_label", graph_4_c3."node2" "_aLias.node1_description"
#      FROM graph_1 AS graph_1_c1
#      LEFT JOIN graph_2 AS graph_2_c2
#      ON graph_1_c1."node1" = graph_2_c2."node1"
#         AND graph_2_c2."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c2."node2") = ?))
#      LEFT JOIN graph_4 AS graph_4_c3
#      ON graph_1_c1."node1" = graph_4_c3."node1"
#         AND graph_4_c3."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_4_c3."node2") = ?))
#      WHERE graph_1_c1."label" = ?
#         AND (graph_1_c1."node2" = ?)
#      ORDER BY graph_1_c1."node1" ASC, graph_2_c2."node2" ASC, graph_4_c3."node2" ASC
#      LIMIT ?
#   PARAS: ['label', ('LANG',), 'any', ('LANG',), 'description', ('LANG',), 'any', ('LANG',), 'P301', ('NODE',), 10000]
# ---------------------------------------------
# [2021-11-18 21:12:43 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."node2" "_aLias.node2"
#      FROM graph_1 AS graph_1_c1
#      WHERE graph_1_c1."label" = ?
#         AND (graph_1_c1."node1" = ?)
#      LIMIT ?
#   PARAS: ['P1630', ('NODE',), 1]
# ---------------------------------------------
# [2021-11-18 21:12:43 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."node1" "_aLias.node1", graph_1_c1."node2" "_aLias.node2", graph_2_c2."node2" "_aLias.node1_label"
#      FROM graph_1 AS graph_1_c1
#      LEFT JOIN graph_2 AS graph_2_c2
#      ON graph_1_c1."node1" = graph_2_c2."node1"
#         AND graph_2_c2."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c2."node2") = ?))
#      WHERE graph_1_c1."label" = ?
#      LIMIT ?
#   PARAS: ['label', ('LANG',), 'any', ('LANG',), 'P1647', 10000]
# ---------------------------------------------
# [2021-11-18 21:12:43 query]: SQL Translation:
# ---------------------------------------------
#   SELECT graph_1_c1."node1" "_aLias.node1", graph_2_c3."node2" "_aLias.node1_label"
#      FROM graph_1 AS graph_1_c1
#      INNER JOIN graph_1 AS graph_1_c2
#      ON graph_1_c1."node1" = graph_1_c2."node1"
#         AND graph_1_c1."label" = ?
#         AND graph_1_c2."label" = ?
#         AND ((graph_1_c2."node2" = ?) AND (graph_1_c1."node2" IN (?, ?, ?)))
#      LEFT JOIN graph_2 AS graph_2_c3
#      ON graph_1_c1."node1" = graph_2_c3."node1"
#         AND graph_2_c3."label" = ?
#         AND ((? = ?) OR (kgtk_lqstring_lang(graph_2_c3."node2") = ?))
#      ORDER BY graph_1_c1."node1" ASC, graph_2_c3."node2" ASC
#      LIMIT ?
#   PARAS: ['P31', 'P424', ('CODE',), 'Q34770', 'Q1288568', 'Q33742', 'label', ('LANG',), 'any', ('LANG',), 10000]
# ---------------------------------------------
#  * Running on http://127.0.0.1:8000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [18/Nov/2021 21:12:51] "GET /browser HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Nov/2021 21:12:52] "GET /browser/static/js/main.91a9f884.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Nov/2021 21:12:53] "GET /browser/images/icons/icon-128x128.png HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Nov/2021 21:12:53] "GET /browser/images/icons/icon-128x128.png HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Nov/2021 21:12:53] "GET /kb/info HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Nov/2021 21:12:53] "GET /browser/static/js/0.10f759a6.chunk.js HTTP/1.1" 200 -
