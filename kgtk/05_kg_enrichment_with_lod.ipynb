# %% [markdown]
# <a href="https://colab.research.google.com/github/versant2612/jnotebooks/blob/main/kgtk/05_kg_enrichment_with_lod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kgtk==1.0.1
# Out:
# Collecting kgtk==1.0.1
#   Downloading kgtk-1.0.1-py3-none-any.whl (550 kB)
#      |████████████████████████████████| 550 kB 28.8 MB/s
# Collecting etk>=2.2.8
#   Downloading etk-2.2.8-py3-none-any.whl (203 kB)
#      |████████████████████████████████| 203 kB 28.4 MB/s
# Collecting sh>=1.13
#   Downloading sh-1.14.2-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.7 MB/s
# Collecting rfc3986
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting rdflib-jsonld>=0.6.2
#   Downloading rdflib_jsonld-0.6.2-py2.py3-none-any.whl (4.0 kB)
# Collecting lz4
#   Downloading lz4-3.1.3-cp37-cp37m-manylinux2010_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 53.2 MB/s
# Collecting pycountry
#   Downloading pycountry-20.7.3.tar.gz (10.1 MB)
#      |████████████████████████████████| 10.1 MB 47.2 MB/s
# Requirement already satisfied: dill>=0.3.2 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (0.3.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (0.11.2)
# Collecting simplejson
#   Downloading simplejson-3.17.6-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 52.1 MB/s
# Collecting torchbiggraph
#   Downloading torchbiggraph-1.0.0-py3-none-any.whl (99 kB)
#      |████████████████████████████████| 99 kB 9.7 MB/s
# Collecting pyshacl>=0.17.1
#   Downloading pyshacl-0.17.2-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 34.8 MB/s
# Collecting mgzip>=0.2.1
#   Downloading mgzip-0.2.1.tar.gz (9.6 kB)
# Collecting shortuuid
#   Downloading shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Collecting redis
#   Downloading redis-4.0.1-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 56.8 MB/s
# Collecting rdflib>=6.0.2
#   Downloading rdflib-6.0.2-py3-none-any.whl (407 kB)
#      |████████████████████████████████| 407 kB 52.6 MB/s
# Collecting pyrallel.lib==0.0.9
#   Downloading pyrallel.lib-0.0.9-py3-none-any.whl (24 kB)
# Collecting iso-639
#   Downloading iso-639-0.4.5.tar.gz (167 kB)
#      |████████████████████████████████| 167 kB 63.5 MB/s
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (0.0)
# Collecting odictliteral
#   Downloading odictliteral-1.0.0.tar.gz (3.1 kB)
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-1.8.5-py3-none-any.whl (26 kB)
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.1.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 7.4 MB/s
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (7.4.0)
# Collecting parsley>=1.3
#   Downloading Parsley-1.3-py2.py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 7.8 MB/s
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (21.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (4.62.3)
# Collecting rltk
#   Downloading rltk-2.0.0a20-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 9.1 MB/s
# Collecting mypy
#   Downloading mypy-0.910-cp37-cp37m-manylinux2010_x86_64.whl (21.5 MB)
#      |████████████████████████████████| 21.5 MB 1.5 MB/s
# Requirement already satisfied: plac==1.1.3 in /usr/local/lib/python3.7/dist-packages (from kgtk==1.0.1) (1.1.3)
# Collecting loguru
#   Downloading loguru-0.5.3-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 5.5 MB/s
# Collecting typing>=3.6
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 7.0 MB/s
# Requirement already satisfied: multiprocess>=0.70 in /usr/local/lib/python3.7/dist-packages (from pyrallel.lib==0.0.9->kgtk==1.0.1) (0.70.12.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (0.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (1.0.6)
# Requirement already satisfied: srsly<1.1.0,>=0.0.6 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (3.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (2.0.6)
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (1.19.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.0.9 in /usr/local/lib/python3.7/dist-packages (from thinc==7.4.0->kgtk==1.0.1) (0.8.2)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->thinc==7.4.0->kgtk==1.0.1) (4.8.2)
# Collecting pyexcel-xls>=0.5.6
#   Downloading pyexcel_xls-0.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2018.9)
# Collecting ujson>=1.35
#   Downloading ujson-4.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (214 kB)
#      |████████████████████████████████| 214 kB 68.8 MB/s
# Collecting ply>=3.11
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 7.4 MB/s
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (4.6.3)
# Collecting langid>=1.1.6
#   Downloading langid-1.1.6.tar.gz (1.9 MB)
#      |████████████████████████████████| 1.9 MB 55.5 MB/s
# Collecting jsonpath-ng>=1.4.3
#   Downloading jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.1.5)
# Collecting cssselect>=1.0.3
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting pygtrie>=2.2
#   Downloading pygtrie-2.4.2.tar.gz (35 kB)
# Collecting dateparser>=0.7.0
#   Downloading dateparser-1.1.0-py2.py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 50.7 MB/s
# Collecting lml>=0.0.1
#   Downloading lml-0.1.0-py2.py3-none-any.whl (10 kB)
# Collecting pyexcel-xlsx>=0.5.6
#   Downloading pyexcel_xlsx-0.6.0-py2.py3-none-any.whl (9.6 kB)
# Collecting langdetect>=1.0.7
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 45.4 MB/s
# Requirement already satisfied: decorator>=4.2.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (4.4.2)
# Requirement already satisfied: pathlib>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.0.1)
# Requirement already satisfied: tzlocal>=1.5.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.5.1)
# Collecting cytoolz>=0.8.2
#   Downloading cytoolz-0.11.2.tar.gz (481 kB)
#      |████████████████████████████████| 481 kB 56.7 MB/s
# Requirement already satisfied: python-dateutil>=2.7.2 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2.8.2)
# Requirement already satisfied: urllib3>=1.22 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.24.3)
# Collecting pyexcel-io>=0.5.6
#   Downloading pyexcel_io-0.6.5-py2.py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 2.5 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.1.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (0.11.2)
# Requirement already satisfied: spacy==2.2.4 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2.2.4)
# Requirement already satisfied: wrapt>=1.10.11 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.13.3)
# Requirement already satisfied: pyparsing>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2.4.7)
# Collecting pyexcel>=0.5.7
#   Downloading pyexcel-0.6.7-py2.py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 9.2 MB/s
# Collecting msgpack-python>=0.5.4
#   Downloading msgpack-python-0.5.6.tar.gz (138 kB)
#      |████████████████████████████████| 138 kB 67.6 MB/s
# Requirement already satisfied: idna>=2.6 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2.10)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (0.2.5)
# Requirement already satisfied: html5lib>=1.0b8 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.0.1)
# Requirement already satisfied: jdcal>=1.3 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.4.1)
# Collecting msgpack-numpy<0.4.4.0
#   Downloading msgpack_numpy-0.4.3.2-py2.py3-none-any.whl (5.2 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.4 MB/s
# Collecting tabula-py>=1.4.3
#   Downloading tabula_py-2.3.0-py3-none-any.whl (12.0 MB)
#      |████████████████████████████████| 12.0 MB 101 kB/s
# Requirement already satisfied: lxml>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (4.2.6)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (1.15.0)
# Collecting ftfy>=4.4.3
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      |████████████████████████████████| 64 kB 2.9 MB/s
# Requirement already satisfied: chardet>=3.0.4 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (3.0.4)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from etk>=2.2.8->kgtk==1.0.1) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.4->etk>=2.2.8->kgtk==1.0.1) (57.4.0)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.7/dist-packages (from dateparser>=0.7.0->etk>=2.2.8->kgtk==1.0.1) (2019.12.20)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from html5lib>=1.0b8->etk>=2.2.8->kgtk==1.0.1) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->thinc==7.4.0->kgtk==1.0.1) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->thinc==7.4.0->kgtk==1.0.1) (3.10.0.2)
# Requirement already satisfied: msgpack>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from msgpack-numpy<0.4.4.0->etk>=2.2.8->kgtk==1.0.1) (1.0.2)
# Collecting texttable>=0.8.2
#   Downloading texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: xlwt in /usr/local/lib/python3.7/dist-packages (from pyexcel-xls>=0.5.6->etk>=2.2.8->kgtk==1.0.1) (1.3.0)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (from pyexcel-xls>=0.5.6->etk>=2.2.8->kgtk==1.0.1) (1.1.0)
# Collecting openpyxl>=2.6.1
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 65.0 MB/s
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.6.1->pyexcel-xlsx>=0.5.6->etk>=2.2.8->kgtk==1.0.1) (1.1.0)
# Collecting owlrl<6.0.0,>=5.2.3
#   Downloading owlrl-5.2.3-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 5.7 MB/s
# Requirement already satisfied: prettytable<3.0.0,>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from pyshacl>=0.17.1->kgtk==1.0.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->etk>=2.2.8->kgtk==1.0.1) (2021.10.8)
# Collecting distro
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting mypy-extensions<0.5.0,>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting typed-ast<1.5.0,>=1.4.0
#   Downloading typed_ast-1.4.3-cp37-cp37m-manylinux1_x86_64.whl (743 kB)
#      |████████████████████████████████| 743 kB 50.8 MB/s
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from mypy->kgtk==1.0.1) (0.10.2)
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: distributed>=1.23 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (1.25.3)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (1.4.1)
# Collecting pandas>=0.22.0
#   Downloading pandas-1.3.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 45.9 MB/s
# Requirement already satisfied: Cython>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (0.29.24)
# Requirement already satisfied: dask>=0.19.2 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (2.12.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from rltk->kgtk==1.0.1) (3.2.2)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (7.1.2)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (5.4.8)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (2.4.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (2.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (3.13)
# Requirement already satisfied: tornado>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (5.1.1)
# Requirement already satisfied: tblib in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (1.7.0)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from distributed>=1.23->rltk->kgtk==1.0.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.0.0->rltk->kgtk==1.0.1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=2.0.0->rltk->kgtk==1.0.1) (1.3.2)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=1.23->rltk->kgtk==1.0.1) (1.0.1)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 49.9 MB/s
# Collecting tokenizers>=0.10.3
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 62.6 MB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1) (0.11.1+cu111)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1) (1.0.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers->kgtk==1.0.1) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 61.5 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.1.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 7.6 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->kgtk==1.0.1) (21.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->kgtk==1.0.1) (3.3.2)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 70.0 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 69.4 MB/s
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers->kgtk==1.0.1) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers->kgtk==1.0.1) (3.0.0)
# Requirement already satisfied: h5py>=2.8 in /usr/local/lib/python3.7/dist-packages (from torchbiggraph->kgtk==1.0.1) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.8->torchbiggraph->kgtk==1.0.1) (1.5.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers->kgtk==1.0.1) (7.1.2)
# Building wheels for collected packages: cytoolz, ftfy, langdetect, langid, mgzip, msgpack-python, pygtrie, typing, iso-639, odictliteral, pycountry, sentence-transformers
#   Building wheel for cytoolz (setup.py) ... done
#   Created wheel for cytoolz: filename=cytoolz-0.11.2-cp37-cp37m-linux_x86_64.whl size=1231136 sha256=7bb593e909a996ae1fe6b3691e76591cb1df84cf109644170e16e6ea78a8bcb3
#   Stored in directory: /root/.cache/pip/wheels/38/70/71/ca13ea3d36ccd0b3d0ec7d7a4ca67522048d695b556bba4f59
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41933 sha256=a6c75076874046b8f09d3dd1ec184abc29e76851ef1c64e0b8ba354fc6fae12b
#   Stored in directory: /root/.cache/pip/wheels/19/f5/38/273eb3b5e76dfd850619312f693716ac4518b498f5ffb6f56d
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=4c0983de0fa691610b1b8fc426858ee159af8aafb1d0305497009f7e4287c04b
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
#   Building wheel for langid (setup.py) ... done
#   Created wheel for langid: filename=langid-1.1.6-py3-none-any.whl size=1941187 sha256=2a4d1572f87389f6b3df886b99a50b4071f5dda06ea9922251aeb496eb7bb174
#   Stored in directory: /root/.cache/pip/wheels/2b/bb/7f/11e4db39477278161e882eadc46fb558949a28b13470fc74b8
#   Building wheel for mgzip (setup.py) ... done
#   Created wheel for mgzip: filename=mgzip-0.2.1-py3-none-any.whl size=10348 sha256=4ff3a30782169417ec26366ed05b8cf3efda9472fbce0c8c7597d11a22489f08
#   Stored in directory: /root/.cache/pip/wheels/d9/57/56/34e22ae1ab1ed3c8108a88dc00f43f59e9763e0c6df0da137f
#   Building wheel for msgpack-python (setup.py) ... done
#   Created wheel for msgpack-python: filename=msgpack_python-0.5.6-cp37-cp37m-linux_x86_64.whl size=305440 sha256=124fd3bfd14bb76a57b39653c52e1aceaba10d7db6bc0ebfa88f146c6c490e7a
#   Stored in directory: /root/.cache/pip/wheels/f8/6c/02/92ebc97f3b99ad5bfc675be2c513f9cb3504fdbe338314f377
#   Building wheel for pygtrie (setup.py) ... done
#   Created wheel for pygtrie: filename=pygtrie-2.4.2-py3-none-any.whl size=19062 sha256=831b38e278d7af75daf9832b2c4de1e0e4d3375f5bbc233fc323ea60e3d0b9a5
#   Stored in directory: /root/.cache/pip/wheels/d3/f8/ba/1d828b1603ea422686eb694253a43cb3a5901ea4696c1e0603
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26324 sha256=a5d81d08add99ad9d558b41e836b9010dccec40555a3ed3e04968b76389d32fb
#   Stored in directory: /root/.cache/pip/wheels/35/f3/15/01aa6571f0a72ee6ae7b827c1491c37a1f72d686fd22b43b0e
#   Building wheel for iso-639 (setup.py) ... done
#   Created wheel for iso-639: filename=iso_639-0.4.5-py3-none-any.whl size=169061 sha256=bd5629e2fa62003fb76154103c47b0bb637910f5a4e95fabcd8f516fd2e4912d
#   Stored in directory: /root/.cache/pip/wheels/47/60/19/6d020fc92138ed1b113a18271e83ea4b5525fe770cb45b9a2e
#   Building wheel for odictliteral (setup.py) ... done
#   Created wheel for odictliteral: filename=odictliteral-1.0.0-py3-none-any.whl size=3122 sha256=b76af4b856be6f0e1f2c44236354239635932fcee8087834821dacba4092fb6b
#   Stored in directory: /root/.cache/pip/wheels/3f/25/10/2ce4f3d7e604b790796f487e5e77a90b544eb2302d0ace109b
#   Building wheel for pycountry (setup.py) ... done
#   Created wheel for pycountry: filename=pycountry-20.7.3-py2.py3-none-any.whl size=10746883 sha256=2375d7de27550d345d255152181f5061d874155fade29889b2004977788dc011
#   Stored in directory: /root/.cache/pip/wheels/57/e8/3f/120ccc1ff7541c108bc5d656e2a14c39da0d824653b62284c6
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=121000 sha256=e5fd1e7f5095db7371e5fc52f89ee0d7958aad5c6d3543a46df0fda5cd39935c
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
# Successfully built cytoolz ftfy langdetect langid mgzip msgpack-python pygtrie typing iso-639 odictliteral pycountry sentence-transformers
# Installing collected packages: isodate, rdflib, pyyaml, lml, typing, tokenizers, texttable, sacremoses, pyexcel-io, ply, pandas, owlrl, openpyxl, huggingface-hub, distro, ujson, typed-ast, transformers, tabula-py, SPARQLWrapper, sentencepiece, rdflib-jsonld, pyshacl, pyrallel.lib, pygtrie, pyexcel-xlsx, pyexcel-xls, pyexcel, mypy-extensions, msgpack-python, msgpack-numpy, langid, langdetect, jsonpath-ng, ftfy, deprecated, dateparser, cytoolz, cssselect, torchbiggraph, simplejson, shortuuid, sh, sentence-transformers, rltk, rfc3986, redis, pycountry, parsley, odictliteral, mypy, mgzip, lz4, loguru, iso-639, etk, kgtk
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 2.5.9
#     Uninstalling openpyxl-2.5.9:
#       Successfully uninstalled openpyxl-2.5.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.4 which is incompatible.
# Successfully installed SPARQLWrapper-1.8.5 cssselect-1.1.0 cytoolz-0.11.2 dateparser-1.1.0 deprecated-1.2.13 distro-1.6.0 etk-2.2.8 ftfy-6.0.3 huggingface-hub-0.1.2 iso-639-0.4.5 isodate-0.6.0 jsonpath-ng-1.5.3 kgtk-1.0.1 langdetect-1.0.9 langid-1.1.6 lml-0.1.0 loguru-0.5.3 lz4-3.1.3 mgzip-0.2.1 msgpack-numpy-0.4.3.2 msgpack-python-0.5.6 mypy-0.910 mypy-extensions-0.4.3 odictliteral-1.0.0 openpyxl-3.0.9 owlrl-5.2.3 pandas-1.3.4 parsley-1.3 ply-3.11 pycountry-20.7.3 pyexcel-0.6.7 pyexcel-io-0.6.5 pyexcel-xls-0.7.0 pyexcel-xlsx-0.6.0 pygtrie-2.4.2 pyrallel.lib-0.0.9 pyshacl-0.17.2 pyyaml-6.0 rdflib-6.0.2 rdflib-jsonld-0.6.2 redis-4.0.1 rfc3986-1.5.0 rltk-2.0.0a20 sacremoses-0.0.46 sentence-transformers-2.1.0 sentencepiece-0.1.96 sh-1.14.2 shortuuid-1.0.8 simplejson-3.17.6 tabula-py-2.3.0 texttable-1.6.4 tokenizers-0.10.3 torchbiggraph-1.0.0 transformers-4.12.5 typed-ast-1.4.3 typing-3.7.4.3 ujson-4.2.0

# %% [markdown]
# # Enriching Wikidata with the Getty KG
#
# The [Getty vocabularies](https://www.getty.edu/research/tools/vocabularies/lod/index.html) contain rich data represented in RDF format.
#
# This notebook shows how graphs like Getty Vocabulary can be used to enrich Wikidata by using `kgtk` operations. We will show this enrichment on the records of people in the `Arnold Schwarzenegger` graph that exist both in Wikidata (with Qnode) and Getty Vocabulary (with ULAN ID). We will enrich their `date of birth` information.
#
# Specifically, we will investigate: *Does Getty contain complementary information to Wikidata about people's date of birth?*
#
# We will use KGTK to import Getty data, align Getty to Wikidata, query dates of birth in both graphs separately, compare the results, and enrich the Wikidata graph with the missing information.

# %%
import os
import json

from kgtk.configure_kgtk_notebooks import ConfigureKGTK
from kgtk.functions import kgtk, kypher

# %% [markdown]
# ## Set up environment path
# Here we set up environment variables that will be used in the following sections, including folders, files like basic databases, query output and so on.

# %%
extra_files_config = {
    "ulan_terms": "ULANOut_2Terms.nt.gz", 
    "ulan_subjects": "ULANOut_1Subjects.nt.gz",
    "ulan_agentmap": "ULANOut_AgentMap.nt.gz", 
    "ulan_biographies": "ULANOut_Biographies.nt.gz",
     "namespaces": "namespaces.tsv"}

open('/root/extra_files.json', 'w').write(json.dumps(extra_files_config))
# Out:
# 206

# %%
# Parameters

# Folder on local machine where to create the output and temporary folders
input_path = None
output_path = "/root/projects"
project_name = "getty-enrichment"
input_files_url="https://github.com/usc-isi-i2/kgtk-tutorial-files/raw/main/datasets/getty"

# %%
files = [
    "all",
    "label"
]
files.extend(extra_files_config.keys())
ck = ConfigureKGTK(files, input_files_url=input_files_url)
ck.configure_kgtk(input_graph_path=input_path,
                  output_path=output_path,
                  project_name=project_name,
                  json_config_file = '/root/extra_files.json')
# Out:
# User home: /root
# Current dir: /content
# KGTK dir: /
# Use-cases dir: //use-cases
# --2021-11-18 22:26:28--  https://github.com/usc-isi-i2/kgtk-tutorial-files/raw/main/datasets/getty/all.tsv.gz
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/usc-isi-i2/kgtk-notebooks/raw/main/datasets/getty/all.tsv.gz [following]
# --2021-11-18 22:26:28--  https://github.com/usc-isi-i2/kgtk-notebooks/raw/main/datasets/getty/all.tsv.gz
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/usc-isi-i2/kgtk-notebooks/main/datasets/getty/all.tsv.gz [following]
# --2021-11-18 22:26:28--  https://raw.githubusercontent.com/usc-isi-i2/kgtk-notebooks/main/datasets/getty/all.tsv.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44564681 (42M) [application/octet-stream]
# Saving to: ‘/root/isi-kgtk-tutorial/input/all.tsv.gz’
#
#      0K .......... .......... .......... .......... ..........  0% 70.6M 1s
#     50K .......... .......... .......... .......... ..........  0% 37.0M 1s
#    100K .......... .......... .......... .......... ..........  0% 47.2M 1s
#    150K .......... .......... .......... .......... ..........  0%  148M 1s
#    200K .......... .......... .......... .......... ..........  0% 47.8M 1s
#    250K .......... .......... .......... .......... ..........  0%  129M 1s
#    300K .......... .......... .......... .......... ..........  0% 70.9M 1s
#    350K .......... .......... .......... .......... ..........  0%  139M 1s
#    400K .......... .......... .......... .......... ..........  1%  101M 1s
#    450K .......... .......... .......... .......... ..........  1%  107M 1s
#    500K .......... .......... .......... .......... ..........  1%  104M 1s
#    550K .......... .......... .......... .......... ..........  1% 91.7M 1s
#    600K .......... .......... .......... .......... ..........  1%  110M 1s
#    650K .......... .......... .......... .......... ..........  1%  121M 1s
#    700K .......... .......... .......... .......... ..........  1% 84.6M 1s
#    750K .......... .......... .......... .......... ..........  1%  125M 1s
#    800K .......... .......... .......... .......... ..........  1%  104M 1s
#    850K .......... .......... .......... .......... ..........  2%  120M 0s
/root/isi-kgtk-tutorial/input/labels.en.tsv.gz
# kypher: kgtk query --graph-cache /root/projects/getty-enrichment/temp.getty-enrichment/wikidata.sqlite3.db
# GRAPH: /root/isi-kgtk-tutorial/input
# kgtk: kgtk
# all: /root/isi-kgtk-tutorial/input/all.tsv.gz
# label: /root/isi-kgtk-tutorial/input/labels.en.tsv.gz
# ulan_terms: /root/isi-kgtk-tutorial/input/ULANOut_2Terms.nt.gz
# ulan_subjects: /root/isi-kgtk-tutorial/input/ULANOut_1Subjects.nt.gz
# ulan_agentmap: /root/isi-kgtk-tutorial/input/ULANOut_AgentMap.nt.gz
# ulan_biographies: /root/isi-kgtk-tutorial/input/ULANOut_Biographies.nt.gz
# namespaces: /root/isi-kgtk-tutorial/input/namespaces.tsv

# %% [markdown]
# ## Approach overview
#
# The Getty knowledge graph consists of [multiple vocabulary files](https://www.getty.edu/research/tools/vocabularies/), including ULAN (Union List of Artist Names), TGN (Thesaurus of Geographic Names), and AAT (Art & Architecture Thesaurus).
# In this tutorial, we will focus on the ULAN vocabulary, which "includes names, rich relationships, notes, sources, and biographical information for artists, architects, firms, studios, repositories, and patrons, both individuals and corporate bodies, named and anonymous". The procedures for the other vocabularies should be analogous as they are also in `.nt` format.
#
# The method that we will use consists of the following 5 steps:
# 1. Import Getty's ULAN file into KGTK
# 2. Align Getty to Wikidata
# 3. Query Wikidata, record known & unknown values
# 4. Query Getty to see if we can find these unknown values
# 5. Append the newly found values to Wikidata

# %% [markdown]
# ## 1. Import Getty's ULAN data into `kgtk`

# %% [markdown]
# As both ULAN and TGN are stored in n-triples (`.nt`) format, we can simply use the `import-ntriples` command.
#
# **Understanding prefixes** Getty conveniently provides an ontology file in an [RDF format](http://vocab.getty.edu/ontology.rdf), which defines the prefixes in the file header. We have transformed this file in KGTK format (`namespaces.tsv`) and we will use it to help KGTK understand prefixes in the data. Here are its contents:

# %%
kgtk("""
    cat -i $GRAPH/namespaces.tsv
""")
# Out:
#               node1             label                                   node2
# 0   xml-schema-type  prefix_expansion       http://www.w3.org/2001/XMLSchema#
# 1    ulan_scopeNote  prefix_expansion  http://vocab.getty.edu/ulan/scopeNote/
# 2          tgn_term  prefix_expansion        http://vocab.getty.edu/tgn/term/
# 3               rrx  prefix_expansion              http://purl.org/r2rml-ext/
# 4     tgn_scopeNote  prefix_expansion   http://vocab.getty.edu/tgn/scopeNote/
# ..              ...               ...                                     ...
# 57             vann  prefix_expansion             http://purl.org/vocab/vann/
# 58            vcard  prefix_expansion        http://www.w3.org/2006/vcard/ns#
# 59      ulan_source  prefix_expansion     http://vocab.getty.edu/ulan/source/
# 60               cc  prefix_expansion          http://creativecommons.org/ns#
# 61             rdfs  prefix_expansion   http://www.w3.org/2000/01/rdf-schema#
#
# [62 rows x 3 columns]

# %% [markdown]
# **Getty files** We will use four files from Getty's ULAN vocabulary:
# 1. `Biography` - which links agents to biographies, using the `gvp:biographyPrefered` property.
# 2. `Agent Map` which links people to their roles ("agents"), through the `foaf:focus` property.
# 3. `Subjects` use `dc:identifier` to link ULAN nodes to their ULAN ID strings.
# 4. `Terms` which links agents to their year of birth and death, using the `gvp:estStart` and `gvp:estEnd` properties
#
# Together, the four files are needed to enable the following path from people to birthdates:
#
# ![ULAN](https://github.com/usc-isi-i2/kgtk-notebooks/blob/main/media/ULAN.png?raw=1)
#
# For convenience, we have uploaded the files in a .gz format to this GitHub repository, we just have to gunzip them before using them in KGTK:

# %%
# !gunzip $GRAPH/ULANOut_2Terms.nt.gz
# !gunzip $GRAPH/ULANOut_1Subjects.nt.gz
# !gunzip $GRAPH/ULANOut_AgentMap.nt.gz
# !gunzip $GRAPH/ULANOut_Biographies.nt.gz

# %% [markdown]
# We can now import each of these four files into KGTK:

# %%
# %%time
kgtk("""
    import-ntriples 
        -i $GRAPH/ULANOut_2Terms.nt
        -o $TEMP/ULAN_term_KGTK.tsv
        --namespace-file $GRAPH/namespaces.tsv
        --namespace-id-use-uuid True 
        --build-new-namespaces False 
        --output-only-used-namespaces True 
        --structured-value-label gvp:structured_value 
        --structured-uri-label gvp:structured_uri 
        --newnode-prefix node 
        --newnode-use-uuid True
    """)
# Out:
# CPU times: user 1 s, sys: 178 ms, total: 1.18 s
# Wall time: 2min 45s

# %%
kgtk("""
    head -i $TEMP/ULAN_term_KGTK.tsv
""")
# Out:
#             node1             label                 node2
# 0  ulan:500523031  gvp:prefLabelGVP  ulan_term:1501308164
# 1  ulan:500523031  skosxl:prefLabel  ulan_term:1501308164
# 2  ulan:500523038  gvp:prefLabelGVP  ulan_term:1501308170
# 3  ulan:500523038  skosxl:prefLabel  ulan_term:1501308170
# 4  ulan:500523041  gvp:prefLabelGVP  ulan_term:1501308173
# 5  ulan:500523041  skosxl:prefLabel  ulan_term:1501308173
# 6  ulan:500523044  gvp:prefLabelGVP  ulan_term:1501308176
# 7  ulan:500523044  skosxl:prefLabel  ulan_term:1501308176
# 8  ulan:500523050  gvp:prefLabelGVP  ulan_term:1501308181
# 9  ulan:500523050  skosxl:prefLabel  ulan_term:1501308181

# %%
# %%time
kgtk("""
    import-ntriples 
        -i $GRAPH/ULANOut_1Subjects.nt
        -o $TEMP/ULAN_subject_KGTK.tsv 
        --namespace-file $GRAPH/namespaces.tsv
        --namespace-id-use-uuid True 
        --build-new-namespaces False 
        --output-only-used-namespaces True 
        --structured-value-label gvp:structured_value 
        --structured-uri-label gvp:structured_uri 
        --newnode-prefix node 
        --newnode-use-uuid True
    """)
# Out:
# CPU times: user 415 ms, sys: 54.9 ms, total: 470 ms
# Wall time: 1min 1s

# %%
kgtk("""
    head -i $TEMP/ULAN_subject_KGTK.tsv
""")
# Out:
#             node1  ...                                        node2
# 0  ulan:500204004  ...                     gvp:UnknownPersonConcept
# 1  ulan:500204004  ...                                            1
# 2  ulan:500204004  ...                    Unknown People by Culture
# 3  ulan:500204004  ...                    Unknown People by Culture
# 4  ulan:500204004  ...                                    500204004
# 5  ulan:500204004  ...  http://opendatacommons.org/licenses/by/1.0/
# 6  ulan:500204004  ...  http://opendatacommons.org/licenses/by/1.0/
# 7  ulan:500204004  ...                                        ulan:
# 8  ulan:500204004  ...          http://vocab.getty.edu/dataset/ulan
# 9  ulan:500372685  ...                     gvp:UnknownPersonConcept
#
# [10 rows x 3 columns]

# %%
# %%time
kgtk("""
    import-ntriples 
        -i $GRAPH/ULANOut_AgentMap.nt
        -o $TEMP/ULAN_agentmap_KGTK.tsv 
        --namespace-file $GRAPH/namespaces.tsv 
        --namespace-id-use-uuid True 
        --build-new-namespaces False 
        --output-only-used-namespaces True 
        --structured-value-label gvp:structured_value 
        --structured-uri-label gvp:structured_uri 
        --newnode-prefix node 
        --newnode-use-uuid True
    """)
# Out:
# CPU times: user 192 ms, sys: 27.1 ms, total: 220 ms
# Wall time: 27.6 s

# %%
kgtk("""
    head -i $TEMP/ULAN_agentmap_KGTK.tsv
""")
# Out:
#             node1       label                 node2
# 0  ulan:500000002  foaf:focus  ulan:500000002-agent
# 1  ulan:500000003  foaf:focus  ulan:500000003-agent
# 2  ulan:500000004  foaf:focus  ulan:500000004-agent
# 3  ulan:500000005  foaf:focus  ulan:500000005-agent
# 4  ulan:500000006  foaf:focus  ulan:500000006-agent
# 5  ulan:500000007  foaf:focus  ulan:500000007-agent
# 6  ulan:500000009  foaf:focus  ulan:500000009-agent
# 7  ulan:500000010  foaf:focus  ulan:500000010-agent
# 8  ulan:500000011  foaf:focus  ulan:500000011-agent
# 9  ulan:500000012  foaf:focus  ulan:500000012-agent

# %%
# %%time
kgtk("""
    import-ntriples 
        -i $GRAPH/ULANOut_Biographies.nt
        -o $TEMP/ULAN_biography_KGTK.tsv 
        --namespace-file $GRAPH/namespaces.tsv
        --namespace-id-use-uuid True 
        --build-new-namespaces False 
        --output-only-used-namespaces True 
        --structured-value-label gvp:structured_value 
        --structured-uri-label gvp:structured_uri 
        --newnode-prefix node 
        --newnode-use-uuid True
    """)
# Out:
# CPU times: user 793 ms, sys: 112 ms, total: 906 ms
# Wall time: 1min 58s

# %%
kgtk("""
    head -i $TEMP/ULAN_biography_KGTK.tsv
""")
# Out:
#                   node1                      label                node2
# 0  ulan:500000002-agent     gvp:biographyPreferred  ulan_bio:4000336014
# 1  ulan:500000003-agent     gvp:biographyPreferred  ulan_bio:4000336015
# 2  ulan:500000004-agent  gvp:biographyNonPreferred  ulan_bio:4000000003
# 3  ulan:500000004-agent     gvp:biographyPreferred  ulan_bio:4000000001
# 4  ulan:500000004-agent  gvp:biographyNonPreferred  ulan_bio:4000000002
# 5  ulan:500000004-agent  gvp:biographyNonPreferred  ulan_bio:4000334645
# 6  ulan:500000004-agent  gvp:biographyNonPreferred  ulan_bio:4000757338
# 7  ulan:500000005-agent     gvp:biographyPreferred  ulan_bio:4000000004
# 8  ulan:500000005-agent  gvp:biographyNonPreferred  ulan_bio:4000000005
# 9  ulan:500000005-agent  gvp:biographyNonPreferred  ulan_bio:4000000006

# %% [markdown]
# After importing each of the files, we can now use KGTK operations on them. We start by `kgtk cat` to concatenate them into a single file for more convenient work with it.

# %%
# %%time
kgtk("""
    cat -i $TEMP/ULAN_term_KGTK.tsv $TEMP/ULAN_subject_KGTK.tsv $TEMP/ULAN_agentmap_KGTK.tsv $TEMP/ULAN_biography_KGTK.tsv 
        -o $TEMP/ULAN_all.tsv
    """)
# Out:
# CPU times: user 113 ms, sys: 26.5 ms, total: 139 ms
# Wall time: 17.5 s

# %% [markdown]
# ## 2. Build Getty-Wikidata Alignment
# Getty provides a `WikidataAlignment` file but our analysis showed that this alignment file is incomplete or out-of-date. Thus, we build our own alignment file, which links ULAN IDs to Wikidata Qnodes.

# %% [markdown]
# We perform a join between the Wikidata and the ULAN graph, through the ULAN identifiers available in both graphs.
# Wikidata uses the property `P245` to map Qnode ids to ULAN identifiers, whereas Getty combines ULAN nodes to IDs with the `dc:identifier` property.
#
# We will use the `skos:exactMatch` property to indicate alignment between ULAN nodes and Wikidata nodes.
#
# *This query is taking our subgraph of Wikidata, and the Getty ULAN graph which is in an entirely different format, and queries the two jointly.*
#
# Let's first see what results we get with this join operation:

# %%
# %%time
kgtk("""
    query -i $all $TEMP/ULAN_all.tsv 
        --match '
            all: (qnode)-[:P245]->(identifier), 
            ULAN: (ulanid)-[p]->(identifier)' 
        --where 'p.label = "dc:identifier"' 
        --return '
                distinct ulanid as node1, 
                "skos:exactMatch" as label, 
                qnode as node2' 
    / add-labels
    """)
# Out:
# CPU times: user 841 ms, sys: 112 ms, total: 953 ms
# Wall time: 2min 13s
#               node1  ...                             node2;label
# 0    ulan:500224955  ...                      'Rachel Carson'@en
# 1    ulan:500281177  ...                   'Gottfried Gruben'@en
# 2    ulan:500001235  ...                            'Sep Ruf'@en
# 3    ulan:500256782  ...            'Margrethe II of Denmark'@en
# 4    ulan:500302331  ...  'Spanish National Research Council'@en
# ..              ...  ...                                     ...
# 538  ulan:500262206  ...                    'John F. Kennedy'@en
# 539  ulan:500247140  ...                        'George Hall'@en
# 540  ulan:500324997  ...                 'Gerhart Rodenwaldt'@en
# 541  ulan:500274474  ...                       'Stuart Craig'@en
# 542  ulan:500030880  ...               'Dwight D. Eisenhower'@en
#
# [543 rows x 4 columns]

# %% [markdown]
# The results look reasonable, so let's go ahead and store the alignment into a KGTK file:

# %%
# %%time
kgtk("""
    query -i $all $TEMP/ULAN_all.tsv 
        --match '
            all: (qnode)-[:P245]->(identifier), 
            ULAN: (ulanid)-[p]->(identifier)' 
        --where 'p.label = "dc:identifier"' 
        --return '
                distinct ulanid as node1, 
                "skos:exactMatch" as label, 
                qnode as node2' 
        -o $TEMP/ULAN_ALIGN.tsv
    """)
# Out:
# CPU times: user 8.66 ms, sys: 13.5 ms, total: 22.2 ms
# Wall time: 575 ms

# %% [markdown]
# We will now run a simple Kypher query to count the Qnodes for which we have ULAN mapping:

# %%
kgtk("""
    query -i $TEMP/ULAN_ALIGN.tsv 
        --match '(ulanid)-[]->(qnode)' 
        --return 'count(distinct qnode) as QNODE'
    """)
# Out:
#    QNODE
# 0    535

# %% [markdown]
# Hmm... So there are 535 Qnodes that correspond to 543 ULAN nodes, which means that we have some Qnodes with more than one ULAN ID. In theory, this should not happen - each entity in Wikidata should correspond to a single ULAN node.
#
# Let's find the Qnodes with multiple mappings, and inspect them closer:

# %%
kgtk("""
    query -i $TEMP/ULAN_ALIGN.tsv
        --match '
            (u1)-[]->(qnode),
            (u2)-[]->(qnode)'
        --where 'u1<u2'
        --return 'qnode as qnode, u1 as ulan1, u2 as ulan2' 
""")
# Out:
#       qnode           ulan1           ulan2
# 0  Q1244372  ulan:500304981  ulan:500305436
# 1   Q127064  ulan:500279772  ulan:500304559
# 2   Q157808  ulan:500210203  ulan:500303345
# 3  Q1600831  ulan:500227540  ulan:500312167
# 4  Q2837755  ulan:500312076  ulan:500312077
# 5  Q2945260  ulan:500251050  ulan:500307043
# 6   Q526170  ulan:500307065  ulan:500312663
# 7    Q66149  ulan:500023792  ulan:500358178

# %% [markdown]
# After manual inspection, we see that https://www.wikidata.org/wiki/Q1244372 indeed has two ULAN identifiers associated with it:
# 1. Allard Pierson Museum (Dutch repository, Amsterdam, contemporary) with id `500304981`
# 2. Universiteit van Amsterdam, Allard Pierson Museum (Dutch repository, Amsterdam, contemporary) with id `500305436`
#
# Thus, the cases where we have multiple ULANs for a Wikidata Qnode are not mapping mistakes, they exist in the data.

# %% [markdown]
# **Finding:** we obtain 543 ULAN mappings for 535 Wikidata nodes. Eight Wikidata Qnodes have two ULAN nodes associated with them.

# %% [markdown]
# ## 3. Query Wikidata (our KG)
# We query our KG subset of Wikidata for these 535 people to see if it has recorded date of birth, using the `P569` property.
#
# We provide first a glimpse of the query results:

# %%
# %%time
kgtk("""
    query -i $TEMP/ULAN_ALIGN.tsv $all 
        --match 'ALIGN: (ulanid)-[]->(qnode), 
                 all: (qnode)-[p:P569]->(birthdate)' 
        --return 'qnode as node1, p.label as label, birthdate as node2' 
    / add-labels
    """)
# Out:
# CPU times: user 49 ms, sys: 11.2 ms, total: 60.1 ms
# Wall time: 5.63 s
#        node1 label  ...                   node1;label         label;label
# 0    Q100948  P569  ...            'Rachel Carson'@en  'date of birth'@en
# 1    Q101771  P569  ...         'Gottfried Gruben'@en  'date of birth'@en
# 2    Q101791  P569  ...                  'Sep Ruf'@en  'date of birth'@en
# 3    Q102139  P569  ...  'Margrethe II of Denmark'@en  'date of birth'@en
# 4    Q102711  P569  ...            'Dennis Hopper'@en  'date of birth'@en
# ..       ...   ...  ...                           ...                 ...
# 295    Q9696  P569  ...          'John F. Kennedy'@en  'date of birth'@en
# 296  Q972381  P569  ...              'George Hall'@en  'date of birth'@en
# 297   Q97416  P569  ...       'Gerhart Rodenwaldt'@en  'date of birth'@en
# 298  Q979511  P569  ...             'Stuart Craig'@en  'date of birth'@en
# 299    Q9916  P569  ...     'Dwight D. Eisenhower'@en  'date of birth'@en
#
# [300 rows x 5 columns]

# %% [markdown]
# Now that we understand the results, we perform the query for all 535 people:

# %%
# %%time
kgtk("""
    query -i $TEMP/ULAN_ALIGN.tsv $all 
        --match 'ALIGN: (ulanid)-[]->(qnode), 
                 all: (qnode)-[p:P569]->(birthdate)' 
        --return 'qnode as node1, p.label as label, birthdate as node2' 
        -o $TEMP/WD_BD.tsv
    """)
# Out:
# CPU times: user 7.32 ms, sys: 12.9 ms, total: 20.2 ms
# Wall time: 565 ms

# %% [markdown]
# And we count the date of birth rows that we find:

# %%
kgtk("""
    query -i $TEMP/WD_BD.tsv
        --match '(qnode)-[]->()' 
        --return 'count(distinct qnode) as Qnode'
    """)
# Out:
#    Qnode
# 0    266

# %% [markdown]
# Again here, each person should in theory have a single date of birth, as it is a functional property. Hence, the finding that we find 300 dates for 266 people needs further investigation:

# %%
kgtk("""
    query -i $TEMP/WD_BD.tsv
        --match '
            (qnode)-[]->(bd1),
            (qnode)-[]->(bd2)'
        --where 'bd1<bd2'
        --return 'qnode as qnode, bd1 as bd1, bd2 as bd2' 
""")
# Out:
#        qnode                       bd1                       bd2
# 0    Q106775  ^1930-10-01T00:00:00Z/11  ^1930-10-02T00:00:00Z/11
# 1     Q11806  ^1735-10-19T00:00:00Z/11  ^1735-10-30T00:00:00Z/11
# 2    Q131981  ^1683-10-30T00:00:00Z/11  ^1683-11-10T00:00:00Z/11
# 3      Q1434   ^0161-01-01T00:00:00Z/9  ^0161-08-31T00:00:00Z/11
# 4   Q1681112   ^1940-01-01T00:00:00Z/9  ^1940-07-13T00:00:00Z/11
# 5    Q174880   ^1515-01-01T00:00:00Z/9  ^1515-03-28T00:00:00Z/11
# 6    Q177847   ^0120-01-01T00:00:00Z/9   ^0125-01-01T00:00:00Z/9
# 7    Q182021  ^1573-04-26T00:00:00Z/11  ^1575-04-26T00:00:00Z/11
# 8      Q2643   ^1943-01-01T00:00:00Z/9  ^1943-02-25T00:00:00Z/11
# 9     Q30875  ^1854-06-16T00:00:00Z/11  ^1854-10-16T00:00:00Z/11
# 10  Q3089653  ^1803-05-20T00:00:00Z/11   ^1805-01-01T00:00:00Z/9
# 11   Q311469  ^1634-12-22T00:00:00Z/11  ^1634-12-24T00:00:00Z/11
# 12      Q352   ^1889-01-01T00:00:00Z/9  ^1889-04-20T00:00:00Z/11
# 13   Q395578   ^1627-01-01T00:00:00Z/9  ^1627-10-26T00:00:00Z/11
# 14    Q43689   ^0339-01-01T00:00:00Z/9   ^0340-01-01T00:00:00Z/9
# 15    Q44281  ^1491-10-23T00:00:00Z/11  ^1491-11-01T00:00:00Z/11
# 16   Q443540  ^1912-10-13T00:00:00Z/11  ^1912-10-31T00:00:00Z/11
# 17   Q472520  ^1898-09-14T00:00:00Z/11  ^1899-09-14T00:00:00Z/11
# 18   Q472520  ^1898-09-14T00:00:00Z/11  ^1898-10-18T00:00:00Z/11
# 19   Q472520  ^1898-09-14T00:00:00Z/11  ^1898-10-08T00:00:00Z/11
# 20   Q472520  ^1898-10-18T00:00:00Z/11  ^1899-09-14T00:00:00Z/11
# 21   Q472520  ^1898-10-08T00:00:00Z/11  ^1899-09-14T00:00:00Z/11
# 22   Q472520  ^1898-10-08T00:00:00Z/11  ^1898-10-18T00:00:00Z/11
# 23     Q5738  ^1797-04-14T00:00:00Z/11  ^1797-04-15T00:00:00Z/11
# 24   Q676555   ^1182-01-01T00:00:00Z/9  ^1182-06-24T00:00:00Z/11
# 25     Q7322   ^1451-01-01T00:00:00Z/9  ^1451-10-31T00:00:00Z/11
# 26     Q7322   ^1451-01-01T00:00:00Z/9  ^1451-09-01T00:00:00Z/11
# 27     Q7322   ^1451-01-01T00:00:00Z/9  ^1451-10-31T00:00:00Z/11
# 28     Q7322   ^1451-01-01T00:00:00Z/9  ^1451-09-01T00:00:00Z/11
# 29     Q7322   ^1450-01-01T00:00:00Z/9   ^1451-01-01T00:00:00Z/9
# 30     Q7322   ^1450-01-01T00:00:00Z/9   ^1451-01-01T00:00:00Z/9
# 31     Q7322   ^1450-01-01T00:00:00Z/9  ^1451-10-31T00:00:00Z/11
# 32     Q7322   ^1450-01-01T00:00:00Z/9  ^1451-09-01T00:00:00Z/11
# 33     Q7322  ^1451-09-01T00:00:00Z/11  ^1451-10-31T00:00:00Z/11
# 34    Q75612  ^1902-11-21T00:00:00Z/11  ^1904-07-14T00:00:00Z/11
# 35     Q8018   ^0354-01-01T00:00:00Z/9  ^0354-11-13T00:00:00Z/11
# 36     Q8018   ^0354-01-01T00:00:00Z/9  ^0354-11-13T00:00:00Z/11
# 37     Q8479  ^1672-05-30T00:00:00Z/11  ^1672-06-09T00:00:00Z/11
# 38      Q855  ^1878-12-18T00:00:00Z/11  ^1879-12-09T00:00:00Z/11
# 39   Q930679  ^1881-09-18T00:00:00Z/11  ^1881-09-28T00:00:00Z/11

# %% [markdown]
# So, indeed some entities have multiple dates of birth recorded. For example, https://www.wikidata.org/wiki/Q75612 has the dates `^1902-11-21T00:00:00Z/11` and `^1904-07-14T00:00:00Z/11`, both in our file and in Wikidata's GUI. Interestingly, these two dates both have a large number of references (5-6), which makes it difficult to pick the right one.

# %% [markdown]
# **Finding:** Out of the 535 people, 266 have date of birth in Wikidata. In total, we obtain 300 dates of birth for these 266 people, due to co-existing conflicting information.

# %% [markdown]
# ## 4. Query Getty

# %% [markdown]
# *Let's see whether Getty can fill the knowledge gaps for the remaining people in Wikidata...*
#
# We now query Getty for the same set of 535 people. In this query, we take the ulan IDs that correspond to the Qnodes of interest, we link these ULAN nodes to ULAN agents or "roles" (using `foaf:focus`), we find their biography (using `gvp:biographyPreferred`), and we get the birth year based on the `gvp:estStart` property. As the birth year is a structured literal, we consider its value (`gvp:structuredValue`).
#
# Getty provides date of birth on a year granularity level. For this purpose, we query Getty for years of birth, and we format them as dates, using the appropriate year precision marker (`/9` in Wikidata and KGTK).

# %%
# %%time
kgtk("""
    query -i $TEMP/ULAN_ALIGN.tsv $TEMP/ULAN_all.tsv
        --match '
                ALIGN: (ulanid)-[]->(qnode), 
                all: (ulanid)-[p0]->(ulanagent), 
                all: (ulanagent)-[p1]->()-[p2]->()-[p3]->(datevalue)' 
        --where '
                p0.label = "foaf:focus" 
                AND p1.label = "gvp:biographyPreferred" 
                AND p2.label = "gvp:estStart" 
                AND p3.label = "gvp:structured_value"' 
        --return '
                  distinct qnode as node1, 
                  "P569" as label, 
                  printf("^%s-01-01T00:00:00Z/9", kgtk_unstringify(datevalue)) as node2' 
    / add-labels
    """)
# Out:
# CPU times: user 575 ms, sys: 72.6 ms, total: 647 ms
# Wall time: 1min 23s
#         node1 label  ...                             node1;label         label;label
# 0     Q100948  P569  ...                      'Rachel Carson'@en  'date of birth'@en
# 1     Q101771  P569  ...                   'Gottfried Gruben'@en  'date of birth'@en
# 2     Q101791  P569  ...                            'Sep Ruf'@en  'date of birth'@en
# 3     Q102139  P569  ...            'Margrethe II of Denmark'@en  'date of birth'@en
# 4    Q1024362  P569  ...  'Spanish National Research Council'@en  'date of birth'@en
# ..        ...   ...  ...                                     ...                 ...
# 535     Q9696  P569  ...                    'John F. Kennedy'@en  'date of birth'@en
# 536   Q972381  P569  ...                        'George Hall'@en  'date of birth'@en
# 537    Q97416  P569  ...                 'Gerhart Rodenwaldt'@en  'date of birth'@en
# 538   Q979511  P569  ...                       'Stuart Craig'@en  'date of birth'@en
# 539     Q9916  P569  ...               'Dwight D. Eisenhower'@en  'date of birth'@en
#
# [540 rows x 5 columns]

# %% [markdown]
# As expected, we obtain dates of birth with a year precision (`/9`). We can thus go ahead and query for the dates of birth for all 535 entities:

# %%
# %%time
kgtk("""
    query -i $TEMP/ULAN_ALIGN.tsv $TEMP/ULAN_all.tsv
        --match 'ALIGN: (ulanid)-[]->(qnode), 
                 all: (ulanid)-[p0]->(ulanagent), 
                 all: (ulanagent)-[p1]->()-[p2]->()-[p3]->(datevalue)' 
        --where 'p0.label = "foaf:focus" AND p1.label = "gvp:biographyPreferred" AND p2.label = "gvp:estStart" AND p3.label = "gvp:structured_value"' 
        --return 'distinct qnode as node1, "P569" as label, printf("^%s-01-01T00:00:00Z/9", kgtk_unstringify(datevalue)) as node2' 
        -o $TEMP/Getty_BD.tsv
    """)
# Out:
# CPU times: user 15.7 ms, sys: 8.4 ms, total: 24.1 ms
# Wall time: 1.19 s

# %% [markdown]
# Let's see how many results we found in Getty:

# %%
kgtk("""
    query -i $TEMP/Getty_BD.tsv 
        --match '(qnode)-[]->()' 
        --return 'count(distinct qnode) as Qnode'
    """)
# Out:
#    Qnode
# 0    535

# %% [markdown]
# **Finding:** We find date of birth for all 535 people in our Getty knowledge graph! We get 540 dates in total, which again means that we have some duplicates.

# %% [markdown]
# ### 4a. How many values are novel?
# Here we count for how many new date of birth we found in Getty:

# %%
# %%time
kgtk("""
    ifnotexists -i $TEMP/Getty_BD.tsv 
        --filter-on $TEMP/WD_BD.tsv 
        --input-keys node1 
        --filter-keys node1 
        -o $TEMP/New_BD.tsv
    """)
# Out:
# CPU times: user 7.27 ms, sys: 9.53 ms, total: 16.8 ms
# Wall time: 539 ms

# %%
kgtk("""
    query -i $TEMP/New_BD.tsv
        --match '(qnode)-[]->()' 
        --return 'count(distinct qnode) as Qnode'
    """)
# Out:
#    Qnode
# 0    269

# %% [markdown]
# **Finding:** There are newly found dates of birth in Getty for 269 entities -- this is expected, given that Getty has 535 values, and Wikidata had 266 values.

# %% [markdown]
# Let's see how many values we get in total:

# %%
kgtk("""
    query -i $TEMP/New_BD.tsv
        --match '(qnode)-[]->()' 
        --return 'count(qnode) as Qnode'
    """)
# Out:
#    Qnode
# 0    273

# %% [markdown]
# **Finding:** We see that in four of the novel cases, Getty has two birth dates for a node.

# %% [markdown]
# ### 4b. Do the known values in Getty and Wikidata match?
# Let's check if the found results in Getty match with those in Wikidata. We first obtain the list of matching birth dates, using the `ifexists` command:

# %%
# %%time
kgtk("""
    ifexists -i $TEMP/Getty_BD.tsv 
        --filter-on $TEMP/WD_BD.tsv 
        --input-keys node1 
        --filter-keys node1 
        -o $TEMP/matching_bd.tsv
    """)
# Out:
# CPU times: user 5.51 ms, sys: 7.96 ms, total: 13.5 ms
# Wall time: 548 ms

# %% [markdown]
# We expect to get birth date values by both sources for 266 nodes:

# %%
kgtk("""
    query -i $TEMP/matching_bd.tsv 
        --match '(qnode)-[]->()' 
        --return 'count(distinct qnode) as Qnode'
    """)
# Out:
#    Qnode
# 0    266

# %% [markdown]
# Ok, our expectation is correct. Let's now see for how many of those nodes do Wikidata and Getty agree on the birth year:

# %%
kgtk("""
    query -i $TEMP/Getty_BD.tsv $TEMP/WD_BD.tsv
        --match '
                Getty: (qnode)-[p]->(v1), 
                WD: (qnode)-[]->(v2)' 
        --where 'kgtk_date_year(v1) = kgtk_date_year(v2)' 
        --return 'count(distinct qnode)'
    """)
# Out:
#    count(DISTINCT graph_5_c1."node1")
# 0                                 250

# %% [markdown]
# Ok, so Getty and Wikidata agree for 250 out of the 266 overlapping entities. Let's inspect the entities for which they contain different information:

# %%
kgtk("""
    query -i $TEMP/Getty_BD.tsv $TEMP/WD_BD.tsv
        --match '
                Getty: (qnode)-[p]->(v1), 
                WD: (qnode)-[]->(v2)' 
        --where 'kgtk_date_year(v1) != kgtk_date_year(v2)' 
        --return 'distinct qnode, kgtk_date_year(v1) as getty_year, kgtk_date_year(v2) as wd_year'
        --order-by 'qnode' 
    / add-labels
    """)
# Out:
#        node1  getty_year  wd_year                        node1;label
# 0    Q177847         100      125            'Lucian of Samosata'@en
# 1    Q177847         100      120            'Lucian of Samosata'@en
# 2    Q182021        1573     1575              'Marie de' Medici'@en
# 3    Q193426        1923     1921                  'Nancy Reagan'@en
# 4   Q2454564        1970     1930                'Charles Kalani'@en
# 5   Q3089653        1803     1805  'Frédéric Bourgeois de Mercey'@en
# 6    Q311469        1635     1634            'Mariana of Austria'@en
# 7   Q3124601        1926     1921                  'LeRoy Neiman'@en
# 8     Q43689         339      340                       'Ambrose'@en
# 9    Q472520        1899     1898                 'Hal B. Wallis'@en
# 10   Q511446        1850     1940               'Luciana Arrighi'@en
# 11   Q525487        1739     1673                 'Jean Chalgrin'@en
# 12    Q53039        1926     1928               'Lina Wertmüller'@en
# 13   Q562596        1955     1956              'David Alan Grier'@en
# 14     Q5738        1796     1797                'Adolphe Thiers'@en
# 15    Q60080        1831     1833               'Wilhelm Dilthey'@en
# 16    Q61423        1854     1853             'Adolf Furtwängler'@en
# 17    Q66149        1792     1791         'Friedrich von Gärtner'@en
# 18   Q676555        1181     1182             'Francis of Assisi'@en
# 19   Q687997        1918     1926                  'Dale Hennesy'@en
# 20   Q725816        1561     1571             'Salomon de Brosse'@en
# 21     Q7322        1451     1450          'Christopher Columbus'@en
# 22    Q75612        1904     1902         'Isaac Bashevis Singer'@en
# 23      Q855        1879     1878                 'Joseph Stalin'@en
# 24   Q937267        1914     1912                  'Frank Thomas'@en

# %% [markdown]
# **Finding:** 250 of the 266 ULAN ids have identical years of birth in Wikidata and Getty. In the remaining cases, the years usually differ a little bit (e.g., 1181 vs 1182).

# %% [markdown]
# # 5. Append the newly found years to our Wikidata subgraph

# %% [markdown]
# We are now ready to insert the 273 new values for the 269 entities from Getty into our Wikidata subgraph.
#
# We first complete each edge with an id, using the `add-id` command:

# %%
# %%time
kgtk("""add-id --debug -i $TEMP/New_BD.tsv --id-style wikidata -o $TEMP/New_BD_with_ID.tsv""")
# Out:
# CPU times: user 7.88 ms, sys: 9.22 ms, total: 17.1 ms
# Wall time: 553 ms

# %% [markdown]
# Finally, we concatenate the original Wikidata graph with the new edges from Getty:

# %%
# %%time
kgtk("""cat -i $all $TEMP/New_BD_with_ID.tsv -o $OUT/all_plus_getty.tsv""")
# Out:
# CPU times: user 95.6 ms, sys: 16.3 ms, total: 112 ms
# Wall time: 13.9 s

# %% [markdown]
# Let's count the number of edges in Wikidata before and after enrichment.
#
# Before:

# %%
# %%time
kgtk("""
    query -i $all 
    --match '(q)-[]->()'
    --return 'count(q)'
    """)
# Out:
# CPU times: user 12.7 ms, sys: 7.52 ms, total: 20.2 ms
# Wall time: 777 ms
#    count(graph_1_c1."node1")
# 0                    2614949

# %% [markdown]
# After:

# %%
# %%time
kgtk("""
    query -i $OUT/all_plus_getty.tsv 
    --match '(q)-[]->()'
    --return 'count(q)'
    """)
# Out:
# CPU times: user 77.9 ms, sys: 13.1 ms, total: 91.1 ms
# Wall time: 10.2 s
#    count(graph_8_c1."node1")
# 0                    2615222

# %% [markdown]
# **Finding:** As expected, the difference is 273 (2,615,222 - 2,614,949) edges.
